# %% [markdown]
# # Exercise 2: Neural Networks
#
# In the previous exercise you implemented a classifier with one linear layer. In this exercise, you will implement a three layer multi-class neural network.
#
# ## Submission guidelines:
#
# Your submission should only include this jupyter notebook named ex2_ID.ipynb (not in zip).
#
# ## Read the following instructions carefully:
#
# 1. This jupyter notebook contains all the step by step instructions needed for this exercise.
# 2. Write **efficient vectorized** code whenever possible.
# 3. You are responsible for the correctness of your code and should add as many tests as you see fit. Tests will not be graded nor checked.
# 4. Do not change the functions we provided you.
# 4. Write your functions in the instructed python modules only. All the logic you write is imported and used using this jupyter notebook. You are allowed to add functions as long as they are located in the python modules and are imported properly.
# 5. You are allowed to use functions and methods from the [Python Standard Library](https://docs.python.org/3/library/) and [numpy](https://www.numpy.org/devdocs/reference/) only. Any other imports are forbidden.
# 6. Your code must run without errors.
# 7. **Before submitting the exercise, restart the kernel and run the notebook from start to finish to make sure everything works. You should include your desired outputs in the output cells to make your code easier to understand.**
# 8. Write your own code. Cheating will not be tolerated.
# 9. Answers to qualitative questions should be written in **markdown** cells (with $\LaTeX$ support).
#
# **TIP:** You may find the following link helpful:
# http://cs231n.github.io/neural-networks-case-study

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pickle
import numpy as np
import os
import sys
import urllib.request
import tarfile
import zipfile
from random import randrange
from functools import partial
import itertools
import seaborn as sns
sns.set()
# specify the way plots behave in jupyter notebook
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12.0, 12.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ## Data download and processing Helper Code

# %%
def maybe_download_and_extract(url, download_dir):
    """
    Download and extract the data if it doesn't already exist.
    Assumes the url is a tar-ball file.
    :param url:
        Internet URL for the tar-file to download.
        Example: "https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz"
    :param download_dir:
        Directory where the downloaded file is saved.
        Example: "data/CIFAR-10/"
    :return:
        Nothing.
    """

    # Filename for saving the file downloaded from the internet.
    # Use the filename from the URL and add it to the download_dir.
    filename = url.split('/')[-1]
    file_path = os.path.join(download_dir, filename)

    # Check if the file already exists.
    # If it exists then we assume it has also been extracted,
    # otherwise we need to download and extract it now.
    if not os.path.exists(file_path):
        # Check if the download directory exists, otherwise create it.
        if not os.path.exists(download_dir):
            os.makedirs(download_dir)

        # Download the file from the internet.
        print("Downloading, This might take several minutes.")
        file_path, _ = urllib.request.urlretrieve(url=url,
                                                  filename=file_path)

        print()
        print("Download finished. Extracting files.")

        if file_path.endswith(".zip"):
            # Unpack the zip-file.
            zipfile.ZipFile(file=file_path, mode="r").extractall(download_dir)
        elif file_path.endswith((".tar.gz", ".tgz")):
            # Unpack the tar-ball.
            tarfile.open(name=file_path, mode="r:gz").extractall(download_dir)

        print("Done.")
    else:
        print("Data has apparently already been downloaded and unpacked.")
        print("If not, delete the dataset folder and try again.")

def load_CIFAR_batch(filename):
    ''' load single batch of cifar '''
    with open(filename, 'rb') as f:
        datadict = pickle.load(f, encoding = 'latin1')
        X = datadict['data']
        Y = datadict['labels']
        X = X.reshape(10000, 3, 32, 32).transpose(0, 2, 3, 1).astype("float")
        Y = np.array(Y)
        return X, Y

def load(ROOT):
    ''' load all of cifar '''
    xs = []
    ys = []
    for b in range(1, 6):
        f = os.path.join(ROOT, 'data_batch_%d' % (b, ))
        X, Y = load_CIFAR_batch(f)
        xs.append(X)
        ys.append(Y)
    Xtr = np.concatenate(xs)
    Ytr = np.concatenate(ys)
    del X, Y
    Xte, Yte = load_CIFAR_batch(os.path.join(ROOT, 'test_batch'))
    return Xtr, Ytr, Xte, Yte

# %% [markdown]
# ## Data Download
#
# The next cell will download and extract CIFAR-10 into `datasets/cifar10/`. The CIFAR-10 dataset consists of 60,000 32x32 color images in 10 classes, with 6,000 images per class. There are 50,000 training images and 10,000 test images. The dataset is divided into five training batches and one test batch, each with 10,000 images. The test batch contains exactly 1,000 randomly-selected images from each class.

# %%
# this cell will download the data if it does not exists
URL = "https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz"
PATH = 'datasets/cifar10/' # the script will create required directories
maybe_download_and_extract(URL, PATH)
# Out:
# Downloading, This might take several minutes.
#
# Download finished. Extracting files.
# Done.

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# **Notice that we are leaving behind the bias trick in this exercise.**

# %%
CIFAR10_PATH = os.path.join(PATH, 'cifar-10-batches-py')
X_train, y_train, X_test, y_test = load(CIFAR10_PATH) # load the entire data
num_classes = 4

X_train = X_train[np.isin(y_train, range(num_classes))]
y_train = y_train[np.isin(y_train, range(num_classes))]
X_test = X_test[np.isin(y_test, range(num_classes))]
y_test = y_test[np.isin(y_test, range(num_classes))]

# define a splitting for the data
num_training = num_classes*5000
num_validation = 1000
num_testing = 1000

# add a validation dataset for hyperparameter optimization
mask = range(num_training)
X_train = X_train[mask]
y_train = y_train[mask]
mask = range(num_validation)
X_val = X_test[mask]
y_val = y_test[mask]
mask = range(num_validation, num_validation+num_testing)
X_test = X_test[mask]
y_test = y_test[mask]

# float64
X_train = X_train.astype(np.float64)
X_val = X_val.astype(np.float64)
X_test = X_test.astype(np.float64)

# subtract the mean from all the images in the batch
mean_image = np.mean(X_train, axis=0)
X_train -= mean_image
X_val -= mean_image
X_test -= mean_image

# flatten all the images in the batch (make sure you understand why this is needed)
X_train = np.reshape(X_train, newshape=(X_train.shape[0], -1))
X_val = np.reshape(X_val, newshape=(X_val.shape[0], -1))
X_test = np.reshape(X_test, newshape=(X_test.shape[0], -1))

print(f"Shape of training set: {X_train.shape}")
print(f"Shape of validation set: {X_val.shape}")
print(f"Shape of test set: {X_test.shape}")

classes = ['plane', 'car', 'bird', 'cat']
# Out:
# Shape of training set: (20000, 3072)
# Shape of validation set: (1000, 3072)
# Shape of test set: (1000, 3072)

# %%
def get_batch(X, y, n=1000):
    rand_items = np.random.randint(0, X.shape[0], size=n)
    images = X[rand_items]
    labels = y[rand_items]
    return images, labels

def make_random_grid(x, y, n=4, convert_to_image=True, random_flag=True):
    if random_flag:
        rand_items = np.random.randint(0, x.shape[0], size=n)
    else:
        rand_items = np.arange(0, x.shape[0])
    images = x[rand_items]
    labels = y[rand_items]
    if convert_to_image:
        grid = np.hstack(np.array([np.asarray((vec_2_img(i) + mean_image), dtype=np.int64) for i in images]))
    else:
        grid = np.hstack(np.array([np.asarray(i, dtype=np.int64) for i in images]))
    print(' '.join('%9s' % classes[labels[j]] for j in range(n)))
    return grid

def vec_2_img(x):
    x = np.reshape(x, (32, 32, 3))
    return x

X_batch, y_batch = get_batch(X_test, y_test, 100)
plt.imshow(make_random_grid(X_batch, y_batch, convert_to_image=True));
# Out:
#      bird     plane       cat      bird

# %% [markdown]
# # Loss

# %% [markdown]
# ## Cross-entropy
#
#
# Complete the function `softmax_loss` using vectorized code. This function takes as input `scores`, labels `y` and outputs the calculated loss as a single number and the gradients with respect to X. **(10 Points)**

# %%
def softmax_loss(scores, y):
    """
    Computes the loss and gradient for softmax classification.

    Inputs:
    - scores: scores of shape (N, C) where scores[i, c] is the score for class c on input X[i].
    - y: Vector of labels

    Returns a tuple of:
    - loss: Scalar giving the loss
    - dx: Gradient of the loss with respect to x
    """
    ###########################################################################
    # TODO: Implement this function                                           #
    ###########################################################################

    n = len(y)
    scores_exp = np.exp(scores)
    scores_exp_sum = np.sum(scores_exp, axis=1).reshape(-1, 1)
    probabilities = scores_exp / scores_exp_sum

    row_indices = np.arange(n)
    losses = -np.log(probabilities[row_indices, y])
    loss = np.mean(losses)

    dx = probabilities
    dx[row_indices, y] -= 1
    dx /= n

    ###########################################################################
    #                              END OF YOUR CODE                           #
    ###########################################################################
    return loss, dx

# %%
# some tests
np.random.seed(42)

num_instances = 5
num_classes = 3

y = np.random.randint(num_classes, size=num_instances)
scores = np.random.randn(num_instances * num_classes).reshape(num_instances, num_classes)
loss, dx = softmax_loss(scores, y)


correct_grad = np.array([[ 0.0062,  0.1751, -0.1813],
         [-0.1463,  0.0561,  0.0901],
         [ 0.0404,  0.0771, -0.1174],
         [ 0.0223,  0.0855, -0.1078],
         [-0.1935,  0.1358,  0.0578]])
correct_loss = 1.7544
assert np.isclose(dx.round(4), correct_grad, rtol=1e-3).all()
assert np.isclose(loss.round(4), correct_loss, rtol=1e-3).all()

# %% [markdown]
# ## L2 Regularization
#
# Regularization is a very important technique in machine learning to prevent overfitting. Mathematically speaking, it adds a regularization term to the loss to penalize larger weights.
# $$
# Loss = Loss + \lambda  \cdot \frac{1}{2} \cdot \sum_{i=0}^k w_k^2
# $$
#
# Implement the L2 regularization part of the loss in the next cell: **(10 Points)**

# %%
def l2_regulariztion_loss(W, reg=0):
    """
    L2 regulariztion loss function, vectorized version.
    - W: a layer's weights.
    - reg: (float) regularization strength
    """
    loss = 0.0
    dW = np.zeros_like(W)
    #############################################################################
    # TODO: Compute the L2 reulariztion loss and its gradient using no
    # explicit loops.                                                           #
    # Store the loss in loss and the gradient in dW.                            #
    #############################################################################

    loss = reg * 0.5 * np.sum(np.square(W))
    dW = reg * W

    #############################################################################
    #                          END OF YOUR CODE                                 #
    #############################################################################
    return loss, dW

# %% [markdown]
# # Neural Network
#
# The implementation of linear regression was (hopefully) simple yet not very modular since the layer, loss and gradient were calculated as a single monolithic function. This would become impractical as we move towards bigger models. As a warmup towards `PyTorch`, we want to build networks using a more modular design so that we can implement different layer types in isolation and easily integrate them together into models with different architectures.
#
# This logic of isolation & integration is at the heart of all popular deep learning frameworks, and is based on two methods each layer holds - a forward and backward pass. The forward function will receive inputs, weights and other parameters and will return both an output and a cache object storing data needed for the backward pass. The backward pass will receive upstream derivatives and the cache, and will return gradients with respect to the inputs and weights. By implementing several types of layers this way, we will be able to easily combine them to build classifiers with different architectures with relative ease.
#
# We will implement a neural network to obtain better results on CIFAR-10.
# Our neural network will be implemented in the following cells. We will train this network using softmax loss and L2 regularization and a ReLU non-linearity.

# %% [markdown]
# ### Fully Connected Layer: Forward Pass.
#
# Implement the function `fc_forward`. **(5 Points)**

# %%
def fc_forward(X, W, b):
    """
    Computes the forward pass for an fully connected layer.
    The input x has shape (N, d_1, ..., d_k) and contains a minibatch of N
    examples, where each example x[i] has shape (d_1, ..., d_k). We will
    reshape each input into a vector of dimension D = d_1 * ... * d_k, and
    then transform it to an output vector of dimension M.
    Inputs:
    - x: A numpy array containing input data, of shape (N, d_1, ..., d_k)
    - W: A numpy array of weights, of shape (D, M)
    - b: A numpy array of biases, of shape (M,)

    Returns a tuple of:
    - out: output, of shape (N, M)
    - cache: (x, w, b)
    """
    out = None
    #############################################################################
    # TODO: Implement the affine forward pass. Store the result in out. You     #
    # will need to reshape the input into rows.                                 #
    #############################################################################

    reshaped_X = X.reshape(X.shape[0], -1)
    out = reshaped_X @ W + b

    #############################################################################
    #                             END OF YOUR CODE                              #
    #############################################################################
    cache = (X.copy(), W.copy(), b.copy())
    return out, cache

# %%
np.random.seed(42)

num_instances = 5
input_shape = (11, 7, 3)
output_shape = 4

X = np.random.randn(num_instances * np.prod(input_shape)).reshape(num_instances, *input_shape)
W = np.random.randn(np.prod(input_shape) * output_shape).reshape(np.prod(input_shape), output_shape)
b = np.random.randn(output_shape)

out, _ = fc_forward(X, W, b)

correct_out = np.array([[16.77132953,  1.43667172, -15.60205534,   7.15789287],
                        [ -8.5994206,  7.59104298,  10.92160126,  17.19394331],
                        [ 4.77874003,  2.25606192,  -6.10944859,  14.76954561],
                        [21.21222953, 17.82329258,   4.53431782,  -9.88327913],
                        [18.83041801, -2.55273817,  14.08484003,  -3.99196171]])

assert np.isclose(out, correct_out, rtol=1e-8).all()

# %% [markdown]
# ### Fully Connected Layer: Backward Pass
#
# Implement the function `fc_backward` **(5 Points)**

# %%
def fc_backward(dout, cache):
    """
    Computes the backward pass for an fully connected layer.
    Try the link in the exercise intructions for more details.

    Inputs:
    - dout: Upstream derivatives
    - cache: Tuple of:
      - X: Input data
      - W: Weights
      - b: Biases

    Returns a tuple of:
    - dx: Gradient with respect to X
    - dw: Gradient with respect to W
    - db: Gradient with respect to b
    """
    x, w, b = cache
    dx, dw, db = 0, 0, 0
    ###########################################################################
    # TODO: Implement the affine backward pass.                               #
    ###########################################################################

    reshaped_X = x.reshape(x.shape[0], -1)
    dx = dout @ w.T
    dx = dx.reshape(x.shape)
    dw = reshaped_X.T @ dout
    db = np.sum(dout, axis=0)

    ###########################################################################
    #                             END OF YOUR CODE                            #
    ###########################################################################
    return dx, dw, db

# %%
def eval_numerical_gradient_array(f, x, df, h=1e-5):
    """
    Evaluate a numeric gradient for a function that accepts a numpy
    array and returns a numpy array.
    """
    grad = np.zeros_like(x)
    it = np.nditer(x, flags=['multi_index'], op_flags=['readwrite'])
    while not it.finished:
        ix = it.multi_index

        oldval = x[ix]
        x[ix] = oldval + h
        pos = f(x).copy()
        x[ix] = oldval - h
        neg = f(x).copy()
        x[ix] = oldval

        grad[ix] = np.sum((pos - neg) * df) / (2 * h)
        it.iternext()
    return grad

# %%
np.random.seed(42)
x = np.random.randn(10, 2, 3)
w = np.random.randn(6, 5)
b = np.random.randn(5)
dout = np.random.randn(10, 5)

dx_num = eval_numerical_gradient_array(lambda x: fc_forward(x, w, b)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: fc_forward(x, w, b)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: fc_forward(x, w, b)[0], b, dout)

out, cache = fc_forward(x,w,b)
dx, dw, db = fc_backward(dout, cache)

assert np.isclose(dw, dw_num, rtol=1e-8).all() # simple test
assert np.isclose(dx, dx_num, rtol=1e-8).all() # simple test
assert np.isclose(db, db_num, rtol=1e-8).all() # simple test

# %% [markdown]
# ### ReLU: Forward Pass
#
# Implement the function `relu_forward`. **(5 Points)**

# %%
def relu_forward(x):
    """
    Computes the forward pass for a layer of rectified linear units (ReLUs).

    Input:
    - x: Inputs, of any shape

    Returns a tuple of:
    - out: Output, of the same shape as x
    - cache: x
    """
    out = None
    #############################################################################
    # TODO: Implement the ReLU forward pass.                                    #
    #############################################################################

    out = np.maximum(0, x)

    #############################################################################
    #                             END OF YOUR CODE                              #
    #############################################################################
    cache = x.copy()
    return out, cache

# %%
x = np.linspace(-0.5, 0.5, num=12).reshape(3, 4)
out, _ = relu_forward(x)
correct_out = np.array([[ 0.,          0.,          0.,          0.,        ],
                        [ 0.,          0.,          0.04545455,  0.13636364,],
                        [ 0.22727273,  0.31818182,  0.40909091,  0.5,       ]])

assert np.isclose(out, correct_out, rtol=1e-8).all() # simple test

# %% [markdown]
# ### ReLU: Backward Pass
#
# Implement the function `relu_backward`. **(5 Points)**

# %%
def relu_backward(dout, cache):
    """
    Computes the backward pass for a layer of rectified linear units (ReLUs).

    Input:
    - dout: Upstream derivatives, of any shape
    - cache: Input x, of same shape as dout

    Returns:
    - dx: Gradient with respect to x
    """
    dx, x = None, cache
    #############################################################################
    # TODO: Implement the ReLU backward pass.                                   #
    #############################################################################

    upstream_grad = dout.copy()
    upstream_grad[x <= 0] = 0
    dx = upstream_grad

    #############################################################################
    #                             END OF YOUR CODE                              #
    #############################################################################
    return dx

# %%
np.random.seed(42)
x = np.random.randn(10, 10)
dout = np.random.randn(*x.shape)
dx_num = eval_numerical_gradient_array(lambda x: relu_forward(x)[0], x, dout)
xx, cache = relu_forward(x)
dx = relu_backward(dout, cache)

assert np.isclose(dx, dx_num, rtol=1e-8).all()  # simple test

# %% [markdown]
# ### Combined Layer
# Next combine the fully connected and relu forward\backward functions togther using the functions in the following cell.
# Remember to use functions you already implemented.
# **(5 Points)**

# %%
def fc_relu_forward(X, W, b):
    """
    Forward pass for a fully connected layer followed by a ReLU.

    Inputs:
    - X: Input to the fc layer
    - W, b: Weights for the fc layer

    Returns:
    - out: Output from the ReLU
    - cache: Object to give to the backward pass
    """
    #############################################################################
    # TODO: Implement the function.                                             #
    #############################################################################

    out, fc_cache = fc_forward(X, W, b)
    out, relu_cache = relu_forward(out)


    #############################################################################
    #                             END OF YOUR CODE                              #
    #############################################################################
    cache = (fc_cache, relu_cache)
    return out, cache


def fc_relu_backward(dout, cache):
    """
    Backward pass for a fully connected layer followed by a ReLU
    Inputs:
    - dout: upstream derivatives
    - cache: parameters calculated during the forward pass

    Returns:
    - dX: derivative w.r.t X
    - dW: derivative w.r.t W
    - db: derivative w.r.t b
    """
    fc_cache, relu_cache = cache
    #############################################################################
    # TODO: Implement the function.                                             #
    #############################################################################

    relu_dout = relu_backward(dout, relu_cache)
    dx, dw, db = fc_backward(relu_dout, fc_cache)

    #############################################################################
    #                             END OF YOUR CODE                              #
    #############################################################################
    return dx, dw, db

# %% [markdown]
# You can check your results in the next cell:

# %%
np.random.seed(42)
x = np.random.randn(10, 2, 3)
w = np.random.randn(6, 5)
b = np.random.randn(5)
dout = np.random.randn(10, 5)

dx_num = eval_numerical_gradient_array(lambda x: fc_relu_forward(x, w, b)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: fc_relu_forward(x, w, b)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: fc_relu_forward(x, w, b)[0], b, dout)

out, cache = fc_relu_forward(x,w,b)
dx, dw, db = fc_relu_backward(dout, cache)

assert np.isclose(dw, dw_num, rtol=1e-8).all() # simple test
assert np.isclose(dx, dx_num, rtol=1e-8).all() # simple test
assert np.isclose(db, db_num, rtol=1e-8).all() # simple test

# %% [markdown]
# # Building the Network

# %% [markdown]
# Complete the class `ThreeLayerNet`. **(35 Points)**

# %%
class ThreeLayerNet(object):
    """
    A three-layer fully-connected neural network. This network has an input dimension of
    N, a hidden layer dimension of H, and performs classification over C classes.
    In our case, we use the same hidden dimension across all hidden layers.
    We train the network with a softmax loss function and L2 regularization on the
    weight matrices. In other words, the network has the following architecture:

    input - fc layer - ReLU - fc layer - ReLu - fc layer - softmax

    The outputs of the third fully-connected layer are the scores for each class.
    """

    def __init__(self, input_size, hidden_size, output_size, std=1e-2):
        """
        Initialize the model. Weights are initialized to small random values and
        biases are initialized to zero. Weights and biases are stored in the
        variable self.params, which is a dictionary with the following keys:

        W1: First layer weights; has shape (D, H)
        b1: First layer biases; has shape (H,)
        W2: Second layer weights; has shape (H, H)
        b2: Second layer biases; has shape (H,)
        W3: Second layer weights; has shape (H, C)
        b3: Second layer biases; has shape (C,)

        Inputs:
        - input_size: The dimension D of the input data.
        - hidden_size: The number of neurons H in each of the hidden layers.
        - output_size: The number of classes C.
        """
        self.params = {}
        self.params['W1'] = std * np.random.randn(input_size, hidden_size)
        self.params['b1'] = np.zeros(hidden_size)
        self.params['W2'] = std * np.random.randn(hidden_size, hidden_size)
        self.params['b2'] = np.zeros(hidden_size)
        self.params['W3'] = std * np.random.randn(hidden_size, output_size)
        self.params['b3'] = np.zeros(output_size)

    def step(self, X, y=None, reg=0.0):
        """
        Compute the loss and gradients for a three layer fully connected neural
        network.

        Inputs:
        - X: Input data of shape (N, D). Each X[i] is a training sample.
        - y: Vector of training labels. This parameter is optional; if it
          is not passed then we only return scores, and if it is passed then we
          instead return the loss and gradients.
        - reg: Regularization coefficient.

        Returns:
        If y is None, return a matrix scores of shape (N, C) where scores[i, c] is
        the score for class c on input X[i].

        If y is not None, instead return a tuple of:
        - loss: Loss (data loss and regularization loss) for this batch of training
          samples.
        - grads: Dictionary mapping parameter names to gradients of those parameters
          with respect to the loss function; has the same keys as self.params.
        """
        # Unpack variables from the params dictionary
        W1, b1 = self.params['W1'], self.params['b1']
        W2, b2 = self.params['W2'], self.params['b2']
        W3, b3 = self.params['W3'], self.params['b3']

        # Compute the forward pass
        scores = None
        #############################################################################
        # TODO: Perform the forward pass, computing the class scores for the input. #
        # Store the result in the scores variable, which should be an array of      #
        # shape (N, C).                                                             #
        #############################################################################

        h1, fc_relu_cache1 = fc_relu_forward(X, W1, b1)
        h2, fc_relu_cache2 = fc_relu_forward(h1, W2, b2)
        scores, fc_cache3 = fc_forward(h2, W3, b3)

        #############################################################################
        #                              END OF YOUR CODE                             #
        #############################################################################

        # If the targets are not given then jump out, we're done
        if y is None:
            return scores

        # Compute the loss
        loss = None
        ###############################################################################
        # After you finished the forward pass, compute the loss. This should include  #
        # both the data loss and L2 regularization for W1, W2, W3. Store the result   #
        # in the variable loss, which should be a scalar. Use the softmax_loss        #
        # and l2_regulariztion_loss functions you implemented.                        #
        ###############################################################################

        loss, dout = softmax_loss(scores, y)

        regularization_loss1, dW1_reg = l2_regulariztion_loss(W1, reg)
        regularization_loss2, dW2_reg = l2_regulariztion_loss(W2, reg)
        regularization_loss3, dW3_reg = l2_regulariztion_loss(W3, reg)

        reg_loss = regularization_loss1 + regularization_loss2 + regularization_loss3
        loss += reg_loss

        #############################################################################
        #                              END OF YOUR CODE                             #
        #############################################################################

        # Backward pass: compute gradients
        grads = {}
        #############################################################################
        # TODO: Compute the backward pass, computing the derivatives of the weights #
        # and biases. Store the results in the grads dictionary. For example,       #
        # grads['W1'] = dW1 + dW1_reg, it stores the gradient on W1, including      #
        # regularization. It should be a matrix of the same size.                   #
        #############################################################################

        dx3, dw3, db3 = fc_backward(dout, fc_cache3)
        dx2, dw2, db2 = fc_relu_backward(dx3, fc_relu_cache2)
        dx1, dw1, db1 = fc_relu_backward(dx2, fc_relu_cache1)

        grads['W1'] = dw1 + dW1_reg
        grads['b1'] = db1

        grads['W2'] = dw2 + dW2_reg
        grads['b2'] = db2

        grads['W3'] = dw3 + + dW3_reg
        grads['b3'] = db3

        #############################################################################
        #                              END OF YOUR CODE                             #
        #############################################################################
        return loss, grads

    def train(self, X, y, X_val, y_val,
              learning_rate=1e-3, reg=1e-5, num_iters=100,
              batch_size=200, verbose=False):
        """
        Train this neural network using stochastic gradient descent.

        Inputs:
        - X: A numpy array of shape (N, D) giving training data.
        - y: A numpy array f shape (N,) giving training label.
        - X_val: A numpy array of shape (N_val, D) giving validation data.
        - y_val: A numpy array of shape (N_val,) giving validation labels.
        - learning_rate: Scalar giving learning rate for optimization.
        - reg: Scalar giving regularization strength.
        - num_iters: Number of steps to take when optimizing.
        - batch_size: Number of training examples to use per step.
        - verbose: boolean; if true print progress during optimization.
        """
        num_train = X.shape[0]
        iterations_per_epoch = max(num_train / batch_size, 1)

        # Use SGD to optimize the parameters in self.model
        loss_history = []
        train_acc_history = []
        val_acc_history = []

        for it in range(num_iters):
            X_batch = None
            y_batch = None
            #########################################################################
            # TODO: Create a random minibatch of training data and labels, storing  #
            # them in X_batch and y_batch respectively.                             #
            #########################################################################

            batch_indices = np.random.randint(0, num_train, size=batch_size)
            X_batch = X[batch_indices]
            y_batch = y[batch_indices]

            #########################################################################
            #                             END OF YOUR CODE                          #
            #########################################################################

            # Compute loss and gradients using the current minibatch
            loss, grads = self.step(X_batch, y=y_batch, reg=reg)
            loss_history.append(loss)
            #########################################################################
            # TODO: Use the gradients in the grads dictionary to update the         #
            # parameters of the network (stored in the dictionary self.params)      #
            # using stochastic gradient descent. You'll need to use the gradients   #
            # stored in the grads dictionary defined above.                         #
            #########################################################################

            self.params['W1'] -= learning_rate * grads['W1']
            self.params['b1'] -= learning_rate * grads['b1']

            self.params['W2'] -= learning_rate * grads['W2']
            self.params['b2'] -= learning_rate * grads['b2']

            self.params['W3'] -= learning_rate * grads['W3']
            self.params['b3'] -= learning_rate * grads['b3']


            #########################################################################
            #                             END OF YOUR CODE                          #
            #########################################################################

            if verbose and (it+1) % 100 == 0:
                print ('iteration %d / %d: loss %f' % (it+1, num_iters, loss))

            # Every epoch, check train and val accuracy.
            if it % iterations_per_epoch == 0:
                train_acc = (self.predict(X_batch) == y_batch).mean()
                val_acc = (self.predict(X_val) == y_val).mean()
                train_acc_history.append(train_acc)
                val_acc_history.append(val_acc)

        return {
          'loss_history': loss_history,
          'train_acc_history': train_acc_history,
          'val_acc_history': val_acc_history,
        }

    def predict(self, X):
        """
        Use the trained weights of this three-layer network to predict labels for
        data points. For each data point we predict scores for each of the C
        classes, and assign each data point to the class with the highest score.

        Inputs:
        - X: data points to classify.

        Returns:
        - y_pred: predicted labels
        """
        y_pred = None
        # Unpack variables from the params dictionary
        W1, b1 = self.params['W1'], self.params['b1']
        W2, b2 = self.params['W2'], self.params['b2']
        W3, b3 = self.params['W3'], self.params['b3']

        ###########################################################################
        # TODO: Implement this function                                           #
        ###########################################################################

        h1, _ = fc_relu_forward(X, W1, b1)
        h2, _ = fc_relu_forward(h1, W2, b2)
        scores, _ = fc_forward(h2, W3, b3)
        y_pred = np.argmax(scores, axis = 1)

        ###########################################################################
        #                              END OF YOUR CODE                           #
        ###########################################################################
        return y_pred

# %%
input_size = 32 * 32 * 3
hidden_size = 128
num_classes = 4
model = ThreeLayerNet(input_size, hidden_size, num_classes)

# %%
stats = model.train(X_train, y_train, X_val, y_val,
            num_iters=1500, batch_size=200,
            learning_rate=1e-3, reg=0, verbose=True)
# Out:
# iteration 100 / 1500: loss 1.084206
# iteration 200 / 1500: loss 1.004476
# iteration 300 / 1500: loss 0.900380
# iteration 400 / 1500: loss 0.825731
# iteration 500 / 1500: loss 0.857723
# iteration 600 / 1500: loss 0.719607
# iteration 700 / 1500: loss 0.754655
# iteration 800 / 1500: loss 0.759193
# iteration 900 / 1500: loss 0.672972
# iteration 1000 / 1500: loss 0.658957
# iteration 1100 / 1500: loss 0.763658
# iteration 1200 / 1500: loss 0.724688
# iteration 1300 / 1500: loss 0.629747
# iteration 1400 / 1500: loss 0.711940
# iteration 1500 / 1500: loss 0.669238

# %%
val_acc = (model.predict(X_val) == y_val).mean()
print ('Validation accuracy: ', val_acc)
# Out:
# Validation accuracy:  0.703

# %%
train_acc = (model.predict(X_train) == y_train).mean()
print ('Training accuracy: ', train_acc)
# Out:
# Training accuracy:  0.7445

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.show()

# %% [markdown]
# ## Hyperparameter Optimization
# Use the validation set to tune hyperparameters by training different models (using the training dataset) and evaluating the performance using the validation dataset. Save the results in a dictionary mapping tuples of the form `(learning_rate, hidden_size, regularization)` to tuples of the form `(training_accuracy, validation_accuracy)`. You should evaluate the best model on the testing dataset and print out the training, validation and testing accuracies for each of the models and provide a clear visualization. Highlight the best model w.r.t the testing accuracy. **(10 Points)**

# %%
# This might take some time, try to expirement with small number of testing parameters before continuing
# You are encouraged to experiment with additional values
learning_rates = [1e-4, 1e-3] # ----- Overriden -----
hidden_sizes = [32, 64, 128, 256]
regularizations = [0, 0.001, 0.1, 0.25]

results = {}
best_val = -1
best_net = None
################################################################################
#                            START OF YOUR CODE                                #
################################################################################
test_accuracies = {}
losses = {}

learning_rates = np.logspace(-7, -3, num=5)

num_iters = 1500

best_reg = 0
best_lr = 0
best_hidden_size = 0
best_train_acc = []
best_val_acc = []
best_losses = []

train_accs = {}
val_accs = {}

for lr in learning_rates:
  for hidden_size in hidden_sizes:
    for reg in regularizations:
      model = ThreeLayerNet(input_size, hidden_size, num_classes)
      stats = model.train(X_train, y_train, X_val, y_val,
                          num_iters=num_iters, batch_size=200,
                          learning_rate=lr, reg=reg, verbose=True)
      train_acc = stats["train_acc_history"]
      val_acc = stats["val_acc_history"]
      results[(lr, hidden_size, reg)] = train_acc[-1], val_acc[-1]

      losses[(lr, hidden_size, reg)] = stats["loss_history"]
      train_accs[(lr, hidden_size, reg)] = train_acc
      val_accs[(lr, hidden_size, reg)] = val_acc
      test_acc = (model.predict(X_test) == y_test).mean()
      test_accuracies[(lr, hidden_size, reg)] = test_acc

      if val_acc[-1] > best_val:
        best_val = val_acc[-1]
        best_net = model
        best_reg = reg
        best_lr = lr
        best_hidden_size = hidden_size
        best_train_acc = train_acc
        best_val_acc = val_acc
        best_losses = stats["loss_history"]


################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# Print out results.
for lr, hidden_size, reg  in sorted(results):
    train_accuracy, val_accuracy = results[(lr, hidden_size, reg)]
    print ('lr %e hidden_size %f reg %f train accuracy: %f val accuracy: %f' % (
                lr, hidden_size, reg, train_accuracy, val_accuracy))

print ('best validation accuracy achieved during cross-validation: %f' % best_val)

test_accuracy = (best_net.predict(X_test) == y_test).mean()
print ('Neural Network on raw pixels final test set accuracy: %f' % test_accuracy)
# Out:
# iteration 100 / 1500: loss 1.387350
# iteration 200 / 1500: loss 1.391081
# iteration 300 / 1500: loss 1.392654
# iteration 400 / 1500: loss 1.386902
# iteration 500 / 1500: loss 1.386671
# iteration 600 / 1500: loss 1.384044
# iteration 700 / 1500: loss 1.386303
# iteration 800 / 1500: loss 1.388406
# iteration 900 / 1500: loss 1.386945
# iteration 1000 / 1500: loss 1.386273
# iteration 1100 / 1500: loss 1.386371
# iteration 1200 / 1500: loss 1.388607
# iteration 1300 / 1500: loss 1.386121
# iteration 1400 / 1500: loss 1.384831
# iteration 1500 / 1500: loss 1.386876
# iteration 100 / 1500: loss 1.393159
# iteration 200 / 1500: loss 1.392533
# iteration 300 / 1500: loss 1.386468
# iteration 400 / 1500: loss 1.395280
# iteration 500 / 1500: loss 1.394344
# iteration 600 / 1500: loss 1.397375
# iteration 700 / 1500: loss 1.391367
# iteration 800 / 1500: loss 1.395851
# iteration 900 / 1500: loss 1.392375
# iteration 1000 / 1500: loss 1.400577
# iteration 1100 / 1500: loss 1.390205
# iteration 1200 / 1500: loss 1.394168
# iteration 1300 / 1500: loss 1.393567
# iteration 1400 / 1500: loss 1.393781
# iteration 1500 / 1500: loss 1.394523
# iteration 100 / 1500: loss 1.880675
# iteration 200 / 1500: loss 1.884841
# iteration 300 / 1500: loss 1.875551
# iteration 400 / 1500: loss 1.883479
# iteration 500 / 1500: loss 1.881261
# iteration 600 / 1500: loss 1.877727
# iteration 700 / 1500: loss 1.888158
# iteration 800 / 1500: loss 1.882760
# iteration 900 / 1500: loss 1.883460
# iteration 1000 / 1500: loss 1.883340
# iteration 1100 / 1500: loss 1.884275
# iteration 1200 / 1500: loss 1.883504
# iteration 1300 / 1500: loss 1.889690
# iteration 1400 / 1500: loss 1.885955
# iteration 1500 / 1500: loss 1.886959
# iteration 100 / 1500: loss 2.652228
# iteration 200 / 1500: loss 2.648884
# iteration 300 / 1500: loss 2.631720
# iteration 400 / 1500: loss 2.641011
# iteration 500 / 1500: loss 2.641368
# iteration 600 / 1500: loss 2.635207
# iteration 700 / 1500: loss 2.645861
# iteration 800 / 1500: loss 2.635564
# iteration 900 / 1500: loss 2.643477
# iteration 1000 / 1500: loss 2.641991
# iteration 1100 / 1500: loss 2.639524
# iteration 1200 / 1500: loss 2.636375
# iteration 1300 / 1500: loss 2.639527
# iteration 1400 / 1500: loss 2.639817
# iteration 1500 / 1500: loss 2.638429
# iteration 100 / 1500: loss 1.388424
# iteration 200 / 1500: loss 1.395318
# iteration 300 / 1500: loss 1.398857
# iteration 400 / 1500: loss 1.398708
# iteration 500 / 1500: loss 1.393944
# iteration 600 / 1500: loss 1.408601
# iteration 700 / 1500: loss 1.396243
# iteration 800 / 1500: loss 1.394872
# iteration 900 / 1500: loss 1.398560
# iteration 1000 / 1500: loss 1.388832
# iteration 1100 / 1500: loss 1.400427
# iteration 1200 / 1500: loss 1.401490
# iteration 1300 / 1500: loss 1.395829
# iteration 1400 / 1500: loss 1.411575
# iteration 1500 / 1500: loss 1.406670
# iteration 100 / 1500: loss 1.392090
# iteration 200 / 1500: loss 1.408110
# iteration 300 / 1500: loss 1.392263
# iteration 400 / 1500: loss 1.405426
# iteration 500 / 1500: loss 1.393743
# iteration 600 / 1500: loss 1.416127
# iteration 700 / 1500: loss 1.407182
# iteration 800 / 1500: loss 1.411751
# iteration 900 / 1500: loss 1.399032
# iteration 1000 / 1500: loss 1.412522
# iteration 1100 / 1500: loss 1.408969
# iteration 1200 / 1500: loss 1.408300
# iteration 1300 / 1500: loss 1.407417
# iteration 1400 / 1500: loss 1.408673
# iteration 1500 / 1500: loss 1.407914
# iteration 100 / 1500: loss 2.379428
# iteration 200 / 1500: loss 2.376744
# iteration 300 / 1500: loss 2.395414
# iteration 400 / 1500: loss 2.380142
# iteration 500 / 1500: loss 2.374743
# iteration 600 / 1500: loss 2.374034
# iteration 700 / 1500: loss 2.375384
# iteration 800 / 1500: loss 2.381981
# iteration 900 / 1500: loss 2.388027
# iteration 1000 / 1500: loss 2.383850
# iteration 1100 / 1500: loss 2.373509
# iteration 1200 / 1500: loss 2.384990
# iteration 1300 / 1500: loss 2.384702
# iteration 1400 / 1500: loss 2.390164
# iteration 1500 / 1500: loss 2.365575
# iteration 100 / 1500: loss 3.908094
# iteration 200 / 1500: loss 3.907665
# iteration 300 / 1500: loss 3.903231
# iteration 400 / 1500: loss 3.916470
# iteration 500 / 1500: loss 3.912826
# iteration 600 / 1500: loss 3.893911
# iteration 700 / 1500: loss 3.907254
# iteration 800 / 1500: loss 3.896846
# iteration 900 / 1500: loss 3.911236
# iteration 1000 / 1500: loss 3.908561
# iteration 1100 / 1500: loss 3.905727
# iteration 1200 / 1500: loss 3.900821
# iteration 1300 / 1500: loss 3.911261
# iteration 1400 / 1500: loss 3.914610
# iteration 1500 / 1500: loss 3.909971
# iteration 100 / 1500: loss 1.405942
# iteration 200 / 1500: loss 1.365259
# iteration 300 / 1500: loss 1.407499
# iteration 400 / 1500: loss 1.396793
# iteration 500 / 1500: loss 1.378009
# iteration 600 / 1500: loss 1.369347
# iteration 700 / 1500: loss 1.385569
# iteration 800 / 1500: loss 1.401965
# iteration 900 / 1500: loss 1.388640
# iteration 1000 / 1500: loss 1.347279
# iteration 1100 / 1500: loss 1.401293
# iteration 1200 / 1500: loss 1.375599
# iteration 1300 / 1500: loss 1.404819
# iteration 1400 / 1500: loss 1.385811
# iteration 1500 / 1500: loss 1.374439
# iteration 100 / 1500: loss 1.466700
# iteration 200 / 1500: loss 1.471686
# iteration 300 / 1500: loss 1.421959
# iteration 400 / 1500: loss 1.432024
# iteration 500 / 1500: loss 1.453682
# iteration 600 / 1500: loss 1.433512
# iteration 700 / 1500: loss 1.489396
# iteration 800 / 1500: loss 1.444976
# iteration 900 / 1500: loss 1.476489
# iteration 1000 / 1500: loss 1.448186
# iteration 1100 / 1500: loss 1.452111
# iteration 1200 / 1500: loss 1.471840
# iteration 1300 / 1500: loss 1.443014
# iteration 1400 / 1500: loss 1.471065
# iteration 1500 / 1500: loss 1.463298
# iteration 100 / 1500: loss 3.477850
# iteration 200 / 1500: loss 3.462762
# iteration 300 / 1500: loss 3.450534
# iteration 400 / 1500: loss 3.446399
# iteration 500 / 1500: loss 3.470246
# iteration 600 / 1500: loss 3.460920
# iteration 700 / 1500: loss 3.459888
# iteration 800 / 1500: loss 3.455434
# iteration 900 / 1500: loss 3.438040
# iteration 1000 / 1500: loss 3.461456
# iteration 1100 / 1500: loss 3.459879
# iteration 1200 / 1500: loss 3.454013
# iteration 1300 / 1500: loss 3.456093
# iteration 1400 / 1500: loss 3.474627
# iteration 1500 / 1500: loss 3.445793
# iteration 100 / 1500: loss 6.501164
# iteration 200 / 1500: loss 6.492365
# iteration 300 / 1500: loss 6.505867
# iteration 400 / 1500: loss 6.465332
# iteration 500 / 1500: loss 6.480033
# iteration 600 / 1500: loss 6.523617
# iteration 700 / 1500: loss 6.489558
# iteration 800 / 1500: loss 6.508836
# iteration 900 / 1500: loss 6.500049
# iteration 1000 / 1500: loss 6.495338
# iteration 1100 / 1500: loss 6.477103
# iteration 1200 / 1500: loss 6.519662
# iteration 1300 / 1500: loss 6.500983
# iteration 1400 / 1500: loss 6.487566
# iteration 1500 / 1500: loss 6.493674
# iteration 100 / 1500: loss 1.404127
# iteration 200 / 1500: loss 1.394140
# iteration 300 / 1500: loss 1.465027
# iteration 400 / 1500: loss 1.455381
# iteration 500 / 1500: loss 1.416852
# iteration 600 / 1500: loss 1.457772
# iteration 700 / 1500: loss 1.380389
# iteration 800 / 1500: loss 1.374323
# iteration 900 / 1500: loss 1.425270
# iteration 1000 / 1500: loss 1.434112
# iteration 1100 / 1500: loss 1.464803
# iteration 1200 / 1500: loss 1.391742
# iteration 1300 / 1500: loss 1.409007
# iteration 1400 / 1500: loss 1.429041
# iteration 1500 / 1500: loss 1.396663
# iteration 100 / 1500: loss 1.438687
# iteration 200 / 1500: loss 1.507980
# iteration 300 / 1500: loss 1.486546
# iteration 400 / 1500: loss 1.468728
# iteration 500 / 1500: loss 1.494337
# iteration 600 / 1500: loss 1.429783
# iteration 700 / 1500: loss 1.511223
# iteration 800 / 1500: loss 1.477481
# iteration 900 / 1500: loss 1.533628
# iteration 1000 / 1500: loss 1.535113
# iteration 1100 / 1500: loss 1.510295
# iteration 1200 / 1500: loss 1.470154
# iteration 1300 / 1500: loss 1.495474
# iteration 1400 / 1500: loss 1.496554
# iteration 1500 / 1500: loss 1.486651
# iteration 100 / 1500: loss 5.735100
# iteration 200 / 1500: loss 5.702246
# iteration 300 / 1500: loss 5.733462
# iteration 400 / 1500: loss 5.770961
# iteration 500 / 1500: loss 5.688933
# iteration 600 / 1500: loss 5.707874
# iteration 700 / 1500: loss 5.699059
# iteration 800 / 1500: loss 5.715198
# iteration 900 / 1500: loss 5.720915
# iteration 1000 / 1500: loss 5.746891
# iteration 1100 / 1500: loss 5.734879
# iteration 1200 / 1500: loss 5.738828
# iteration 1300 / 1500: loss 5.672112
# iteration 1400 / 1500: loss 5.801046
# iteration 1500 / 1500: loss 5.690142
# iteration 100 / 1500: loss 12.108918
# iteration 200 / 1500: loss 12.144323
# iteration 300 / 1500: loss 12.158328
# iteration 400 / 1500: loss 12.114898
# iteration 500 / 1500: loss 12.130754
# iteration 600 / 1500: loss 12.116437
# iteration 700 / 1500: loss 12.110578
# iteration 800 / 1500: loss 12.118090
# iteration 900 / 1500: loss 12.112226
# iteration 1000 / 1500: loss 12.082343
# iteration 1100 / 1500: loss 12.127983
# iteration 1200 / 1500: loss 12.084943
# iteration 1300 / 1500: loss 12.103881
# iteration 1400 / 1500: loss 12.089755
# iteration 1500 / 1500: loss 12.123249
# iteration 100 / 1500: loss 1.400357
# iteration 200 / 1500: loss 1.403389
# iteration 300 / 1500: loss 1.397847
# iteration 400 / 1500: loss 1.407522
# iteration 500 / 1500: loss 1.404611
# iteration 600 / 1500: loss 1.395725
# iteration 700 / 1500: loss 1.396389
# iteration 800 / 1500: loss 1.400996
# iteration 900 / 1500: loss 1.397164
# iteration 1000 / 1500: loss 1.398756
# iteration 1100 / 1500: loss 1.398665
# iteration 1200 / 1500: loss 1.399810
# iteration 1300 / 1500: loss 1.404237
# iteration 1400 / 1500: loss 1.394554
# iteration 1500 / 1500: loss 1.402043
# iteration 100 / 1500: loss 1.397040
# iteration 200 / 1500: loss 1.389555
# iteration 300 / 1500: loss 1.390088
# iteration 400 / 1500: loss 1.392120
# iteration 500 / 1500: loss 1.392550
# iteration 600 / 1500: loss 1.396817
# iteration 700 / 1500: loss 1.389852
# iteration 800 / 1500: loss 1.389243
# iteration 900 / 1500: loss 1.392544
# iteration 1000 / 1500: loss 1.388880
# iteration 1100 / 1500: loss 1.392881
# iteration 1200 / 1500: loss 1.392862
# iteration 1300 / 1500: loss 1.393620
# iteration 1400 / 1500: loss 1.387494
# iteration 1500 / 1500: loss 1.386780
# iteration 100 / 1500: loss 1.890317
# iteration 200 / 1500: loss 1.893295
# iteration 300 / 1500: loss 1.889467
# iteration 400 / 1500: loss 1.895017
# iteration 500 / 1500: loss 1.888275
# iteration 600 / 1500: loss 1.892058
# iteration 700 / 1500: loss 1.890377
# iteration 800 / 1500: loss 1.890605
# iteration 900 / 1500: loss 1.890824
# iteration 1000 / 1500: loss 1.887774
# iteration 1100 / 1500: loss 1.893365
# iteration 1200 / 1500: loss 1.888644
# iteration 1300 / 1500: loss 1.890891
# iteration 1400 / 1500: loss 1.890570
# iteration 1500 / 1500: loss 1.893630
# iteration 100 / 1500: loss 2.632203
# iteration 200 / 1500: loss 2.633602
# iteration 300 / 1500: loss 2.635478
# iteration 400 / 1500: loss 2.637807
# iteration 500 / 1500: loss 2.634182
# iteration 600 / 1500: loss 2.636135
# iteration 700 / 1500: loss 2.631996
# iteration 800 / 1500: loss 2.629802
# iteration 900 / 1500: loss 2.632907
# iteration 1000 / 1500: loss 2.631155
# iteration 1100 / 1500: loss 2.631987
# iteration 1200 / 1500: loss 2.637246
# iteration 1300 / 1500: loss 2.631886
# iteration 1400 / 1500: loss 2.632879
# iteration 1500 / 1500: loss 2.630920
# iteration 100 / 1500: loss 1.395704
# iteration 200 / 1500: loss 1.376512
# iteration 300 / 1500: loss 1.381433
# iteration 400 / 1500: loss 1.401185
# iteration 500 / 1500: loss 1.391544
# iteration 600 / 1500: loss 1.377100
# iteration 700 / 1500: loss 1.389653
# iteration 800 / 1500: loss 1.389658
# iteration 900 / 1500: loss 1.383500
# iteration 1000 / 1500: loss 1.379809
# iteration 1100 / 1500: loss 1.379893
# iteration 1200 / 1500: loss 1.377634
# iteration 1300 / 1500: loss 1.382308
# iteration 1400 / 1500: loss 1.375844
# iteration 1500 / 1500: loss 1.380993
# iteration 100 / 1500: loss 1.400723
# iteration 200 / 1500: loss 1.397408
# iteration 300 / 1500: loss 1.392943
# iteration 400 / 1500: loss 1.394143
# iteration 500 / 1500: loss 1.399421
# iteration 600 / 1500: loss 1.395524
# iteration 700 / 1500: loss 1.396841
# iteration 800 / 1500: loss 1.396296
# iteration 900 / 1500: loss 1.391897
# iteration 1000 / 1500: loss 1.400258
# iteration 1100 / 1500: loss 1.396578
# iteration 1200 / 1500: loss 1.400355
# iteration 1300 / 1500: loss 1.397137
# iteration 1400 / 1500: loss 1.394270
# iteration 1500 / 1500: loss 1.395215
# iteration 100 / 1500: loss 2.417463
# iteration 200 / 1500: loss 2.415275
# iteration 300 / 1500: loss 2.398401
# iteration 400 / 1500: loss 2.401593
# iteration 500 / 1500: loss 2.398084
# iteration 600 / 1500: loss 2.404524
# iteration 700 / 1500: loss 2.398437
# iteration 800 / 1500: loss 2.397102
# iteration 900 / 1500: loss 2.399626
# iteration 1000 / 1500: loss 2.407734
# iteration 1100 / 1500: loss 2.398689
# iteration 1200 / 1500: loss 2.393734
# iteration 1300 / 1500: loss 2.388189
# iteration 1400 / 1500: loss 2.385993
# iteration 1500 / 1500: loss 2.398927
# iteration 100 / 1500: loss 3.906597
# iteration 200 / 1500: loss 3.894334
# iteration 300 / 1500: loss 3.920233
# iteration 400 / 1500: loss 3.910467
# iteration 500 / 1500: loss 3.919263
# iteration 600 / 1500: loss 3.902792
# iteration 700 / 1500: loss 3.910002
# iteration 800 / 1500: loss 3.911604
# iteration 900 / 1500: loss 3.912198
# iteration 1000 / 1500: loss 3.912097
# iteration 1100 / 1500: loss 3.907770
# iteration 1200 / 1500: loss 3.900934
# iteration 1300 / 1500: loss 3.907433
# iteration 1400 / 1500: loss 3.899098
# iteration 1500 / 1500: loss 3.905003
# iteration 100 / 1500: loss 1.404776
# iteration 200 / 1500: loss 1.416019
# iteration 300 / 1500: loss 1.412828
# iteration 400 / 1500: loss 1.411348
# iteration 500 / 1500: loss 1.423250
# iteration 600 / 1500: loss 1.393870
# iteration 700 / 1500: loss 1.391831
# iteration 800 / 1500: loss 1.403401
# iteration 900 / 1500: loss 1.388973
# iteration 1000 / 1500: loss 1.395937
# iteration 1100 / 1500: loss 1.391373
# iteration 1200 / 1500: loss 1.399714
# iteration 1300 / 1500: loss 1.402541
# iteration 1400 / 1500: loss 1.414963
# iteration 1500 / 1500: loss 1.384760
# iteration 100 / 1500: loss 1.420918
# iteration 200 / 1500: loss 1.435382
# iteration 300 / 1500: loss 1.461499
# iteration 400 / 1500: loss 1.437723
# iteration 500 / 1500: loss 1.435476
# iteration 600 / 1500: loss 1.450659
# iteration 700 / 1500: loss 1.421443
# iteration 800 / 1500: loss 1.458986
# iteration 900 / 1500: loss 1.405384
# iteration 1000 / 1500: loss 1.420141
# iteration 1100 / 1500: loss 1.449272
# iteration 1200 / 1500: loss 1.436194
# iteration 1300 / 1500: loss 1.429156
# iteration 1400 / 1500: loss 1.435372
# iteration 1500 / 1500: loss 1.426779
# iteration 100 / 1500: loss 3.478735
# iteration 200 / 1500: loss 3.457354
# iteration 300 / 1500: loss 3.447380
# iteration 400 / 1500: loss 3.484641
# iteration 500 / 1500: loss 3.446360
# iteration 600 / 1500: loss 3.438113
# iteration 700 / 1500: loss 3.434975
# iteration 800 / 1500: loss 3.436848
# iteration 900 / 1500: loss 3.473812
# iteration 1000 / 1500: loss 3.441422
# iteration 1100 / 1500: loss 3.441292
# iteration 1200 / 1500: loss 3.448239
# iteration 1300 / 1500: loss 3.453587
# iteration 1400 / 1500: loss 3.456072
# iteration 1500 / 1500: loss 3.450596
# iteration 100 / 1500: loss 6.545830
# iteration 200 / 1500: loss 6.552867
# iteration 300 / 1500: loss 6.536874
# iteration 400 / 1500: loss 6.528676
# iteration 500 / 1500: loss 6.561117
# iteration 600 / 1500: loss 6.543797
# iteration 700 / 1500: loss 6.531142
# iteration 800 / 1500: loss 6.537687
# iteration 900 / 1500: loss 6.534764
# iteration 1000 / 1500: loss 6.519626
# iteration 1100 / 1500: loss 6.526305
# iteration 1200 / 1500: loss 6.553175
# iteration 1300 / 1500: loss 6.533395
# iteration 1400 / 1500: loss 6.498484
# iteration 1500 / 1500: loss 6.507646
# iteration 100 / 1500: loss 1.430711
# iteration 200 / 1500: loss 1.400333
# iteration 300 / 1500: loss 1.388529
# iteration 400 / 1500: loss 1.419946
# iteration 500 / 1500: loss 1.384977
# iteration 600 / 1500: loss 1.397329
# iteration 700 / 1500: loss 1.371607
# iteration 800 / 1500: loss 1.359496
# iteration 900 / 1500: loss 1.382630
# iteration 1000 / 1500: loss 1.402876
# iteration 1100 / 1500: loss 1.373527
# iteration 1200 / 1500: loss 1.380434
# iteration 1300 / 1500: loss 1.357706
# iteration 1400 / 1500: loss 1.385257
# iteration 1500 / 1500: loss 1.379937
# iteration 100 / 1500: loss 1.558647
# iteration 200 / 1500: loss 1.491676
# iteration 300 / 1500: loss 1.528735
# iteration 400 / 1500: loss 1.462952
# iteration 500 / 1500: loss 1.474426
# iteration 600 / 1500: loss 1.462016
# iteration 700 / 1500: loss 1.476411
# iteration 800 / 1500: loss 1.484763
# iteration 900 / 1500: loss 1.500291
# iteration 1000 / 1500: loss 1.464862
# iteration 1100 / 1500: loss 1.442460
# iteration 1200 / 1500: loss 1.474681
# iteration 1300 / 1500: loss 1.407593
# iteration 1400 / 1500: loss 1.441113
# iteration 1500 / 1500: loss 1.437235
# iteration 100 / 1500: loss 5.708178
# iteration 200 / 1500: loss 5.706747
# iteration 300 / 1500: loss 5.693991
# iteration 400 / 1500: loss 5.717541
# iteration 500 / 1500: loss 5.709170
# iteration 600 / 1500: loss 5.695406
# iteration 700 / 1500: loss 5.703275
# iteration 800 / 1500: loss 5.679151
# iteration 900 / 1500: loss 5.695932
# iteration 1000 / 1500: loss 5.656810
# iteration 1100 / 1500: loss 5.689378
# iteration 1200 / 1500: loss 5.675934
# iteration 1300 / 1500: loss 5.686032
# iteration 1400 / 1500: loss 5.677983
# iteration 1500 / 1500: loss 5.643722
# iteration 100 / 1500: loss 12.117779
# iteration 200 / 1500: loss 12.071102
# iteration 300 / 1500: loss 12.115168
# iteration 400 / 1500: loss 12.058772
# iteration 500 / 1500: loss 12.056008
# iteration 600 / 1500: loss 12.059527
# iteration 700 / 1500: loss 12.058075
# iteration 800 / 1500: loss 12.024443
# iteration 900 / 1500: loss 12.095366
# iteration 1000 / 1500: loss 12.014080
# iteration 1100 / 1500: loss 12.025716
# iteration 1200 / 1500: loss 12.028444
# iteration 1300 / 1500: loss 12.056626
# iteration 1400 / 1500: loss 12.035070
# iteration 1500 / 1500: loss 11.989471
# iteration 100 / 1500: loss 1.393168
# iteration 200 / 1500: loss 1.395695
# iteration 300 / 1500: loss 1.391752
# iteration 400 / 1500: loss 1.391303
# iteration 500 / 1500: loss 1.382955
# iteration 600 / 1500: loss 1.383758
# iteration 700 / 1500: loss 1.383210
# iteration 800 / 1500: loss 1.383755
# iteration 900 / 1500: loss 1.386262
# iteration 1000 / 1500: loss 1.385750
# iteration 1100 / 1500: loss 1.385679
# iteration 1200 / 1500: loss 1.384226
# iteration 1300 / 1500: loss 1.383441
# iteration 1400 / 1500: loss 1.379089
# iteration 1500 / 1500: loss 1.383091
# iteration 100 / 1500: loss 1.388980
# iteration 200 / 1500: loss 1.390604
# iteration 300 / 1500: loss 1.394311
# iteration 400 / 1500: loss 1.390336
# iteration 500 / 1500: loss 1.394772
# iteration 600 / 1500: loss 1.394754
# iteration 700 / 1500: loss 1.388406
# iteration 800 / 1500: loss 1.391247
# iteration 900 / 1500: loss 1.387528
# iteration 1000 / 1500: loss 1.384656
# iteration 1100 / 1500: loss 1.391573
# iteration 1200 / 1500: loss 1.384049
# iteration 1300 / 1500: loss 1.391687
# iteration 1400 / 1500: loss 1.382677
# iteration 1500 / 1500: loss 1.385527
# iteration 100 / 1500: loss 1.891739
# iteration 200 / 1500: loss 1.880982
# iteration 300 / 1500: loss 1.883125
# iteration 400 / 1500: loss 1.881486
# iteration 500 / 1500: loss 1.883449
# iteration 600 / 1500: loss 1.882607
# iteration 700 / 1500: loss 1.884019
# iteration 800 / 1500: loss 1.883522
# iteration 900 / 1500: loss 1.877842
# iteration 1000 / 1500: loss 1.877705
# iteration 1100 / 1500: loss 1.878834
# iteration 1200 / 1500: loss 1.875032
# iteration 1300 / 1500: loss 1.881630
# iteration 1400 / 1500: loss 1.877596
# iteration 1500 / 1500: loss 1.876717
# iteration 100 / 1500: loss 2.619892
# iteration 200 / 1500: loss 2.627711
# iteration 300 / 1500: loss 2.616735
# iteration 400 / 1500: loss 2.622206
# iteration 500 / 1500: loss 2.622632
# iteration 600 / 1500: loss 2.624117
# iteration 700 / 1500: loss 2.618105
# iteration 800 / 1500: loss 2.616017
# iteration 900 / 1500: loss 2.617586
# iteration 1000 / 1500: loss 2.610919
# iteration 1100 / 1500: loss 2.613354
# iteration 1200 / 1500: loss 2.610863
# iteration 1300 / 1500: loss 2.611122
# iteration 1400 / 1500: loss 2.609285
# iteration 1500 / 1500: loss 2.600209
# iteration 100 / 1500: loss 1.389894
# iteration 200 / 1500: loss 1.389701
# iteration 300 / 1500: loss 1.391540
# iteration 400 / 1500: loss 1.374940
# iteration 500 / 1500: loss 1.377522
# iteration 600 / 1500: loss 1.377728
# iteration 700 / 1500: loss 1.366323
# iteration 800 / 1500: loss 1.369165
# iteration 900 / 1500: loss 1.375664
# iteration 1000 / 1500: loss 1.376574
# iteration 1100 / 1500: loss 1.366315
# iteration 1200 / 1500: loss 1.373402
# iteration 1300 / 1500: loss 1.365605
# iteration 1400 / 1500: loss 1.378790
# iteration 1500 / 1500: loss 1.369279
# iteration 100 / 1500: loss 1.405777
# iteration 200 / 1500: loss 1.404065
# iteration 300 / 1500: loss 1.398550
# iteration 400 / 1500: loss 1.404099
# iteration 500 / 1500: loss 1.392205
# iteration 600 / 1500: loss 1.403554
# iteration 700 / 1500: loss 1.391860
# iteration 800 / 1500: loss 1.392292
# iteration 900 / 1500: loss 1.390069
# iteration 1000 / 1500: loss 1.388009
# iteration 1100 / 1500: loss 1.385383
# iteration 1200 / 1500: loss 1.385601
# iteration 1300 / 1500: loss 1.384182
# iteration 1400 / 1500: loss 1.388393
# iteration 1500 / 1500: loss 1.377870
# iteration 100 / 1500: loss 2.391848
# iteration 200 / 1500: loss 2.388727
# iteration 300 / 1500: loss 2.396935
# iteration 400 / 1500: loss 2.383093
# iteration 500 / 1500: loss 2.386077
# iteration 600 / 1500: loss 2.379628
# iteration 700 / 1500: loss 2.376593
# iteration 800 / 1500: loss 2.376875
# iteration 900 / 1500: loss 2.379294
# iteration 1000 / 1500: loss 2.373319
# iteration 1100 / 1500: loss 2.370116
# iteration 1200 / 1500: loss 2.368713
# iteration 1300 / 1500: loss 2.370631
# iteration 1400 / 1500: loss 2.367758
# iteration 1500 / 1500: loss 2.364532
# iteration 100 / 1500: loss 3.900767
# iteration 200 / 1500: loss 3.888830
# iteration 300 / 1500: loss 3.880580
# iteration 400 / 1500: loss 3.889197
# iteration 500 / 1500: loss 3.887265
# iteration 600 / 1500: loss 3.879911
# iteration 700 / 1500: loss 3.878821
# iteration 800 / 1500: loss 3.879781
# iteration 900 / 1500: loss 3.880812
# iteration 1000 / 1500: loss 3.874498
# iteration 1100 / 1500: loss 3.862779
# iteration 1200 / 1500: loss 3.866522
# iteration 1300 / 1500: loss 3.849856
# iteration 1400 / 1500: loss 3.856360
# iteration 1500 / 1500: loss 3.857843
# iteration 100 / 1500: loss 1.381679
# iteration 200 / 1500: loss 1.429857
# iteration 300 / 1500: loss 1.369643
# iteration 400 / 1500: loss 1.389211
# iteration 500 / 1500: loss 1.374741
# iteration 600 / 1500: loss 1.323109
# iteration 700 / 1500: loss 1.358062
# iteration 800 / 1500: loss 1.345736
# iteration 900 / 1500: loss 1.321285
# iteration 1000 / 1500: loss 1.325823
# iteration 1100 / 1500: loss 1.316681
# iteration 1200 / 1500: loss 1.332949
# iteration 1300 / 1500: loss 1.277507
# iteration 1400 / 1500: loss 1.317310
# iteration 1500 / 1500: loss 1.297190
# iteration 100 / 1500: loss 1.402845
# iteration 200 / 1500: loss 1.381662
# iteration 300 / 1500: loss 1.378447
# iteration 400 / 1500: loss 1.369023
# iteration 500 / 1500: loss 1.360853
# iteration 600 / 1500: loss 1.351590
# iteration 700 / 1500: loss 1.352519
# iteration 800 / 1500: loss 1.345178
# iteration 900 / 1500: loss 1.367764
# iteration 1000 / 1500: loss 1.356224
# iteration 1100 / 1500: loss 1.338962
# iteration 1200 / 1500: loss 1.334967
# iteration 1300 / 1500: loss 1.336651
# iteration 1400 / 1500: loss 1.338795
# iteration 1500 / 1500: loss 1.297233
# iteration 100 / 1500: loss 3.445394
# iteration 200 / 1500: loss 3.444667
# iteration 300 / 1500: loss 3.421345
# iteration 400 / 1500: loss 3.418661
# iteration 500 / 1500: loss 3.394813
# iteration 600 / 1500: loss 3.406753
# iteration 700 / 1500: loss 3.393595
# iteration 800 / 1500: loss 3.386812
# iteration 900 / 1500: loss 3.392555
# iteration 1000 / 1500: loss 3.395460
# iteration 1100 / 1500: loss 3.384848
# iteration 1200 / 1500: loss 3.344064
# iteration 1300 / 1500: loss 3.362322
# iteration 1400 / 1500: loss 3.370641
# iteration 1500 / 1500: loss 3.365495
# iteration 100 / 1500: loss 6.540209
# iteration 200 / 1500: loss 6.529041
# iteration 300 / 1500: loss 6.518783
# iteration 400 / 1500: loss 6.510779
# iteration 500 / 1500: loss 6.501941
# iteration 600 / 1500: loss 6.504985
# iteration 700 / 1500: loss 6.493461
# iteration 800 / 1500: loss 6.469527
# iteration 900 / 1500: loss 6.479182
# iteration 1000 / 1500: loss 6.425394
# iteration 1100 / 1500: loss 6.455557
# iteration 1200 / 1500: loss 6.425249
# iteration 1300 / 1500: loss 6.450933
# iteration 1400 / 1500: loss 6.436886
# iteration 1500 / 1500: loss 6.438533
# iteration 100 / 1500: loss 1.435965
# iteration 200 / 1500: loss 1.415495
# iteration 300 / 1500: loss 1.343957
# iteration 400 / 1500: loss 1.305599
# iteration 500 / 1500: loss 1.316671
# iteration 600 / 1500: loss 1.307951
# iteration 700 / 1500: loss 1.328301
# iteration 800 / 1500: loss 1.316923
# iteration 900 / 1500: loss 1.260422
# iteration 1000 / 1500: loss 1.223440
# iteration 1100 / 1500: loss 1.236084
# iteration 1200 / 1500: loss 1.242239
# iteration 1300 / 1500: loss 1.207465
# iteration 1400 / 1500: loss 1.248921
# iteration 1500 / 1500: loss 1.194993
# iteration 100 / 1500: loss 1.555633
# iteration 200 / 1500: loss 1.450387
# iteration 300 / 1500: loss 1.384722
# iteration 400 / 1500: loss 1.364961
# iteration 500 / 1500: loss 1.345953
# iteration 600 / 1500: loss 1.358069
# iteration 700 / 1500: loss 1.347680
# iteration 800 / 1500: loss 1.370149
# iteration 900 / 1500: loss 1.309084
# iteration 1000 / 1500: loss 1.276459
# iteration 1100 / 1500: loss 1.275545
# iteration 1200 / 1500: loss 1.285710
# iteration 1300 / 1500: loss 1.324028
# iteration 1400 / 1500: loss 1.245267
# iteration 1500 / 1500: loss 1.263273
# iteration 100 / 1500: loss 5.723472
# iteration 200 / 1500: loss 5.685251
# iteration 300 / 1500: loss 5.648270
# iteration 400 / 1500: loss 5.618076
# iteration 500 / 1500: loss 5.591931
# iteration 600 / 1500: loss 5.596221
# iteration 700 / 1500: loss 5.558615
# iteration 800 / 1500: loss 5.576757
# iteration 900 / 1500: loss 5.568264
# iteration 1000 / 1500: loss 5.564765
# iteration 1100 / 1500: loss 5.541695
# iteration 1200 / 1500: loss 5.534265
# iteration 1300 / 1500: loss 5.482380
# iteration 1400 / 1500: loss 5.481249
# iteration 1500 / 1500: loss 5.469182
# iteration 100 / 1500: loss 12.025443
# iteration 200 / 1500: loss 12.066189
# iteration 300 / 1500: loss 11.990015
# iteration 400 / 1500: loss 12.005943
# iteration 500 / 1500: loss 11.946565
# iteration 600 / 1500: loss 11.920159
# iteration 700 / 1500: loss 11.924544
# iteration 800 / 1500: loss 11.942869
# iteration 900 / 1500: loss 11.870747
# iteration 1000 / 1500: loss 11.853619
# iteration 1100 / 1500: loss 11.861745
# iteration 1200 / 1500: loss 11.835095
# iteration 1300 / 1500: loss 11.797233
# iteration 1400 / 1500: loss 11.799162
# iteration 1500 / 1500: loss 11.801944
# iteration 100 / 1500: loss 1.377274
# iteration 200 / 1500: loss 1.368931
# iteration 300 / 1500: loss 1.370164
# iteration 400 / 1500: loss 1.363787
# iteration 500 / 1500: loss 1.347155
# iteration 600 / 1500: loss 1.351687
# iteration 700 / 1500: loss 1.323226
# iteration 800 / 1500: loss 1.341231
# iteration 900 / 1500: loss 1.322847
# iteration 1000 / 1500: loss 1.305638
# iteration 1100 / 1500: loss 1.273647
# iteration 1200 / 1500: loss 1.300454
# iteration 1300 / 1500: loss 1.297945
# iteration 1400 / 1500: loss 1.240115
# iteration 1500 / 1500: loss 1.281473
# iteration 100 / 1500: loss 1.394658
# iteration 200 / 1500: loss 1.390961
# iteration 300 / 1500: loss 1.386695
# iteration 400 / 1500: loss 1.375185
# iteration 500 / 1500: loss 1.377936
# iteration 600 / 1500: loss 1.365795
# iteration 700 / 1500: loss 1.348710
# iteration 800 / 1500: loss 1.356705
# iteration 900 / 1500: loss 1.349953
# iteration 1000 / 1500: loss 1.329482
# iteration 1100 / 1500: loss 1.315679
# iteration 1200 / 1500: loss 1.330038
# iteration 1300 / 1500: loss 1.307424
# iteration 1400 / 1500: loss 1.282275
# iteration 1500 / 1500: loss 1.294695
# iteration 100 / 1500: loss 1.875422
# iteration 200 / 1500: loss 1.865915
# iteration 300 / 1500: loss 1.863023
# iteration 400 / 1500: loss 1.849590
# iteration 500 / 1500: loss 1.853963
# iteration 600 / 1500: loss 1.845256
# iteration 700 / 1500: loss 1.827519
# iteration 800 / 1500: loss 1.817904
# iteration 900 / 1500: loss 1.773803
# iteration 1000 / 1500: loss 1.815508
# iteration 1100 / 1500: loss 1.806058
# iteration 1200 / 1500: loss 1.795217
# iteration 1300 / 1500: loss 1.743919
# iteration 1400 / 1500: loss 1.784042
# iteration 1500 / 1500: loss 1.770140
# iteration 100 / 1500: loss 2.609395
# iteration 200 / 1500: loss 2.597337
# iteration 300 / 1500: loss 2.590712
# iteration 400 / 1500: loss 2.576216
# iteration 500 / 1500: loss 2.565204
# iteration 600 / 1500: loss 2.538423
# iteration 700 / 1500: loss 2.539437
# iteration 800 / 1500: loss 2.512400
# iteration 900 / 1500: loss 2.482550
# iteration 1000 / 1500: loss 2.498220
# iteration 1100 / 1500: loss 2.464106
# iteration 1200 / 1500: loss 2.429336
# iteration 1300 / 1500: loss 2.448719
# iteration 1400 / 1500: loss 2.426021
# iteration 1500 / 1500: loss 2.428143
# iteration 100 / 1500: loss 1.367524
# iteration 200 / 1500: loss 1.358260
# iteration 300 / 1500: loss 1.344177
# iteration 400 / 1500: loss 1.326005
# iteration 500 / 1500: loss 1.324289
# iteration 600 / 1500: loss 1.305677
# iteration 700 / 1500: loss 1.273151
# iteration 800 / 1500: loss 1.227329
# iteration 900 / 1500: loss 1.305578
# iteration 1000 / 1500: loss 1.298274
# iteration 1100 / 1500: loss 1.268783
# iteration 1200 / 1500: loss 1.194915
# iteration 1300 / 1500: loss 1.209663
# iteration 1400 / 1500: loss 1.204650
# iteration 1500 / 1500: loss 1.163197
# iteration 100 / 1500: loss 1.384020
# iteration 200 / 1500: loss 1.375183
# iteration 300 / 1500: loss 1.359707
# iteration 400 / 1500: loss 1.347020
# iteration 500 / 1500: loss 1.314995
# iteration 600 / 1500: loss 1.320376
# iteration 700 / 1500: loss 1.267014
# iteration 800 / 1500: loss 1.279507
# iteration 900 / 1500: loss 1.282983
# iteration 1000 / 1500: loss 1.280011
# iteration 1100 / 1500: loss 1.221846
# iteration 1200 / 1500: loss 1.216409
# iteration 1300 / 1500: loss 1.195842
# iteration 1400 / 1500: loss 1.142493
# iteration 1500 / 1500: loss 1.195311
# iteration 100 / 1500: loss 2.380158
# iteration 200 / 1500: loss 2.368232
# iteration 300 / 1500: loss 2.349756
# iteration 400 / 1500: loss 2.347285
# iteration 500 / 1500: loss 2.330892
# iteration 600 / 1500: loss 2.310735
# iteration 700 / 1500: loss 2.281730
# iteration 800 / 1500: loss 2.278908
# iteration 900 / 1500: loss 2.232312
# iteration 1000 / 1500: loss 2.242082
# iteration 1100 / 1500: loss 2.259809
# iteration 1200 / 1500: loss 2.184895
# iteration 1300 / 1500: loss 2.166709
# iteration 1400 / 1500: loss 2.215716
# iteration 1500 / 1500: loss 2.096571
# iteration 100 / 1500: loss 3.871405
# iteration 200 / 1500: loss 3.843948
# iteration 300 / 1500: loss 3.812321
# iteration 400 / 1500: loss 3.801117
# iteration 500 / 1500: loss 3.748569
# iteration 600 / 1500: loss 3.728406
# iteration 700 / 1500: loss 3.686789
# iteration 800 / 1500: loss 3.659521
# iteration 900 / 1500: loss 3.714455
# iteration 1000 / 1500: loss 3.618338
# iteration 1100 / 1500: loss 3.615771
# iteration 1200 / 1500: loss 3.558561
# iteration 1300 / 1500: loss 3.523184
# iteration 1400 / 1500: loss 3.466907
# iteration 1500 / 1500: loss 3.544969
# iteration 100 / 1500: loss 1.336178
# iteration 200 / 1500: loss 1.258479
# iteration 300 / 1500: loss 1.300652
# iteration 400 / 1500: loss 1.256609
# iteration 500 / 1500: loss 1.201631
# iteration 600 / 1500: loss 1.169759
# iteration 700 / 1500: loss 1.220708
# iteration 800 / 1500: loss 1.134855
# iteration 900 / 1500: loss 1.146901
# iteration 1000 / 1500: loss 1.142538
# iteration 1100 / 1500: loss 1.108742
# iteration 1200 / 1500: loss 1.074092
# iteration 1300 / 1500: loss 1.010831
# iteration 1400 / 1500: loss 1.060414
# iteration 1500 / 1500: loss 1.100506
# iteration 100 / 1500: loss 1.315141
# iteration 200 / 1500: loss 1.300424
# iteration 300 / 1500: loss 1.314297
# iteration 400 / 1500: loss 1.234944
# iteration 500 / 1500: loss 1.186649
# iteration 600 / 1500: loss 1.174192
# iteration 700 / 1500: loss 1.117818
# iteration 800 / 1500: loss 1.204526
# iteration 900 / 1500: loss 1.129595
# iteration 1000 / 1500: loss 1.163732
# iteration 1100 / 1500: loss 1.120722
# iteration 1200 / 1500: loss 1.105813
# iteration 1300 / 1500: loss 1.042681
# iteration 1400 / 1500: loss 1.078428
# iteration 1500 / 1500: loss 1.060850
# iteration 100 / 1500: loss 3.389685
# iteration 200 / 1500: loss 3.353558
# iteration 300 / 1500: loss 3.286725
# iteration 400 / 1500: loss 3.253172
# iteration 500 / 1500: loss 3.228687
# iteration 600 / 1500: loss 3.255301
# iteration 700 / 1500: loss 3.162146
# iteration 800 / 1500: loss 3.206477
# iteration 900 / 1500: loss 3.147274
# iteration 1000 / 1500: loss 3.140191
# iteration 1100 / 1500: loss 3.114172
# iteration 1200 / 1500: loss 3.071168
# iteration 1300 / 1500: loss 3.006675
# iteration 1400 / 1500: loss 3.058820
# iteration 1500 / 1500: loss 3.026310
# iteration 100 / 1500: loss 6.376750
# iteration 200 / 1500: loss 6.406865
# iteration 300 / 1500: loss 6.263680
# iteration 400 / 1500: loss 6.269601
# iteration 500 / 1500: loss 6.251653
# iteration 600 / 1500: loss 6.187805
# iteration 700 / 1500: loss 6.106936
# iteration 800 / 1500: loss 6.140288
# iteration 900 / 1500: loss 6.000026
# iteration 1000 / 1500: loss 5.955457
# iteration 1100 / 1500: loss 5.893034
# iteration 1200 / 1500: loss 5.893780
# iteration 1300 / 1500: loss 5.853603
# iteration 1400 / 1500: loss 5.840413
# iteration 1500 / 1500: loss 5.813598
# iteration 100 / 1500: loss 1.269123
# iteration 200 / 1500: loss 1.150324
# iteration 300 / 1500: loss 1.168016
# iteration 400 / 1500: loss 1.166824
# iteration 500 / 1500: loss 1.119912
# iteration 600 / 1500: loss 1.052256
# iteration 700 / 1500: loss 1.004978
# iteration 800 / 1500: loss 1.009619
# iteration 900 / 1500: loss 0.991362
# iteration 1000 / 1500: loss 1.071851
# iteration 1100 / 1500: loss 0.947968
# iteration 1200 / 1500: loss 1.076985
# iteration 1300 / 1500: loss 0.995653
# iteration 1400 / 1500: loss 0.913818
# iteration 1500 / 1500: loss 0.959547
# iteration 100 / 1500: loss 1.329668
# iteration 200 / 1500: loss 1.245299
# iteration 300 / 1500: loss 1.211333
# iteration 400 / 1500: loss 1.163100
# iteration 500 / 1500: loss 1.124842
# iteration 600 / 1500: loss 1.085417
# iteration 700 / 1500: loss 1.032961
# iteration 800 / 1500: loss 1.057214
# iteration 900 / 1500: loss 1.032310
# iteration 1000 / 1500: loss 0.957432
# iteration 1100 / 1500: loss 1.014047
# iteration 1200 / 1500: loss 0.998420
# iteration 1300 / 1500: loss 1.019029
# iteration 1400 / 1500: loss 1.037990
# iteration 1500 / 1500: loss 1.013492
# iteration 100 / 1500: loss 5.550279
# iteration 200 / 1500: loss 5.464475
# iteration 300 / 1500: loss 5.430912
# iteration 400 / 1500: loss 5.384557
# iteration 500 / 1500: loss 5.347278
# iteration 600 / 1500: loss 5.281966
# iteration 700 / 1500: loss 5.248042
# iteration 800 / 1500: loss 5.218699
# iteration 900 / 1500: loss 5.223046
# iteration 1000 / 1500: loss 5.172531
# iteration 1100 / 1500: loss 5.206785
# iteration 1200 / 1500: loss 5.224814
# iteration 1300 / 1500: loss 5.145196
# iteration 1400 / 1500: loss 5.117530
# iteration 1500 / 1500: loss 5.112996
# iteration 100 / 1500: loss 11.904974
# iteration 200 / 1500: loss 11.729694
# iteration 300 / 1500: loss 11.651781
# iteration 400 / 1500: loss 11.610503
# iteration 500 / 1500: loss 11.434358
# iteration 600 / 1500: loss 11.366205
# iteration 700 / 1500: loss 11.324840
# iteration 800 / 1500: loss 11.215787
# iteration 900 / 1500: loss 11.220812
# iteration 1000 / 1500: loss 11.193435
# iteration 1100 / 1500: loss 11.104146
# iteration 1200 / 1500: loss 10.972507
# iteration 1300 / 1500: loss 10.994095
# iteration 1400 / 1500: loss 10.839588
# iteration 1500 / 1500: loss 10.861547
# iteration 100 / 1500: loss 1.324207
# iteration 200 / 1500: loss 1.262821
# iteration 300 / 1500: loss 1.091617
# iteration 400 / 1500: loss 1.010726
# iteration 500 / 1500: loss 1.018949
# iteration 600 / 1500: loss 0.989890
# iteration 700 / 1500: loss 0.942196
# iteration 800 / 1500: loss 0.937571
# iteration 900 / 1500: loss 0.872368
# iteration 1000 / 1500: loss 0.744808
# iteration 1100 / 1500: loss 0.768896
# iteration 1200 / 1500: loss 0.895304
# iteration 1300 / 1500: loss 0.901592
# iteration 1400 / 1500: loss 0.828682
# iteration 1500 / 1500: loss 0.702401
# iteration 100 / 1500: loss 1.341228
# iteration 200 / 1500: loss 1.270101
# iteration 300 / 1500: loss 1.114826
# iteration 400 / 1500: loss 1.016683
# iteration 500 / 1500: loss 0.990443
# iteration 600 / 1500: loss 0.964306
# iteration 700 / 1500: loss 0.910782
# iteration 800 / 1500: loss 0.867564
# iteration 900 / 1500: loss 0.844276
# iteration 1000 / 1500: loss 0.802961
# iteration 1100 / 1500: loss 0.914833
# iteration 1200 / 1500: loss 0.865647
# iteration 1300 / 1500: loss 0.797102
# iteration 1400 / 1500: loss 0.805913
# iteration 1500 / 1500: loss 0.723130
# iteration 100 / 1500: loss 1.793700
# iteration 200 / 1500: loss 1.693729
# iteration 300 / 1500: loss 1.480595
# iteration 400 / 1500: loss 1.411290
# iteration 500 / 1500: loss 1.474539
# iteration 600 / 1500: loss 1.536216
# iteration 700 / 1500: loss 1.306923
# iteration 800 / 1500: loss 1.245870
# iteration 900 / 1500: loss 1.255551
# iteration 1000 / 1500: loss 1.253572
# iteration 1100 / 1500: loss 1.198200
# iteration 1200 / 1500: loss 1.139574
# iteration 1300 / 1500: loss 1.183304
# iteration 1400 / 1500: loss 1.121390
# iteration 1500 / 1500: loss 1.279022
# iteration 100 / 1500: loss 2.503764
# iteration 200 / 1500: loss 2.316768
# iteration 300 / 1500: loss 2.225833
# iteration 400 / 1500: loss 2.046144
# iteration 500 / 1500: loss 1.938267
# iteration 600 / 1500: loss 1.920426
# iteration 700 / 1500: loss 1.754819
# iteration 800 / 1500: loss 1.759561
# iteration 900 / 1500: loss 1.651300
# iteration 1000 / 1500: loss 1.566646
# iteration 1100 / 1500: loss 1.554387
# iteration 1200 / 1500: loss 1.586390
# iteration 1300 / 1500: loss 1.416716
# iteration 1400 / 1500: loss 1.503191
# iteration 1500 / 1500: loss 1.325764
# iteration 100 / 1500: loss 1.231872
# iteration 200 / 1500: loss 1.061235
# iteration 300 / 1500: loss 1.042466
# iteration 400 / 1500: loss 1.000234
# iteration 500 / 1500: loss 0.928400
# iteration 600 / 1500: loss 0.852344
# iteration 700 / 1500: loss 0.880260
# iteration 800 / 1500: loss 0.820699
# iteration 900 / 1500: loss 0.815829
# iteration 1000 / 1500: loss 0.742552
# iteration 1100 / 1500: loss 0.733570
# iteration 1200 / 1500: loss 0.813346
# iteration 1300 / 1500: loss 0.713453
# iteration 1400 / 1500: loss 0.752942
# iteration 1500 / 1500: loss 0.674610
# iteration 100 / 1500: loss 1.260652
# iteration 200 / 1500: loss 1.072838
# iteration 300 / 1500: loss 0.933960
# iteration 400 / 1500: loss 0.922790
# iteration 500 / 1500: loss 0.945672
# iteration 600 / 1500: loss 0.833281
# iteration 700 / 1500: loss 0.901966
# iteration 800 / 1500: loss 0.742842
# iteration 900 / 1500: loss 0.858942
# iteration 1000 / 1500: loss 0.766468
# iteration 1100 / 1500: loss 0.766499
# iteration 1200 / 1500: loss 0.787035
# iteration 1300 / 1500: loss 0.798816
# iteration 1400 / 1500: loss 0.739848
# iteration 1500 / 1500: loss 0.777418
# iteration 100 / 1500: loss 2.219295
# iteration 200 / 1500: loss 2.074473
# iteration 300 / 1500: loss 1.925472
# iteration 400 / 1500: loss 1.859725
# iteration 500 / 1500: loss 1.895249
# iteration 600 / 1500: loss 1.761942
# iteration 700 / 1500: loss 1.765740
# iteration 800 / 1500: loss 1.850210
# iteration 900 / 1500: loss 1.658499
# iteration 1000 / 1500: loss 1.617345
# iteration 1100 / 1500: loss 1.634461
# iteration 1200 / 1500: loss 1.529925
# iteration 1300 / 1500: loss 1.572336
# iteration 1400 / 1500: loss 1.497708
# iteration 1500 / 1500: loss 1.518385
# iteration 100 / 1500: loss 3.673793
# iteration 200 / 1500: loss 3.405201
# iteration 300 / 1500: loss 3.157814
# iteration 400 / 1500: loss 3.062195
# iteration 500 / 1500: loss 2.948639
# iteration 600 / 1500: loss 2.766411
# iteration 700 / 1500: loss 2.620470
# iteration 800 / 1500: loss 2.613474
# iteration 900 / 1500: loss 2.484318
# iteration 1000 / 1500: loss 2.409406
# iteration 1100 / 1500: loss 2.368916
# iteration 1200 / 1500: loss 2.296328
# iteration 1300 / 1500: loss 2.076706
# iteration 1400 / 1500: loss 2.046438
# iteration 1500 / 1500: loss 1.934135
# iteration 100 / 1500: loss 1.149369
# iteration 200 / 1500: loss 1.003858
# iteration 300 / 1500: loss 0.964054
# iteration 400 / 1500: loss 0.948106
# iteration 500 / 1500: loss 0.883778
# iteration 600 / 1500: loss 0.759925
# iteration 700 / 1500: loss 0.807932
# iteration 800 / 1500: loss 0.806707
# iteration 900 / 1500: loss 0.744971
# iteration 1000 / 1500: loss 0.662368
# iteration 1100 / 1500: loss 0.748226
# iteration 1200 / 1500: loss 0.697039
# iteration 1300 / 1500: loss 0.727336
# iteration 1400 / 1500: loss 0.697206
# iteration 1500 / 1500: loss 0.641540
# iteration 100 / 1500: loss 1.122663
# iteration 200 / 1500: loss 0.938927
# iteration 300 / 1500: loss 0.920229
# iteration 400 / 1500: loss 0.870880
# iteration 500 / 1500: loss 0.842908
# iteration 600 / 1500: loss 0.808711
# iteration 700 / 1500: loss 0.876240
# iteration 800 / 1500: loss 0.750742
# iteration 900 / 1500: loss 0.773013
# iteration 1000 / 1500: loss 0.806830
# iteration 1100 / 1500: loss 0.769669
# iteration 1200 / 1500: loss 0.727057
# iteration 1300 / 1500: loss 0.751265
# iteration 1400 / 1500: loss 0.707794
# iteration 1500 / 1500: loss 0.698102
# iteration 100 / 1500: loss 3.118647
# iteration 200 / 1500: loss 2.936281
# iteration 300 / 1500: loss 2.864958
# iteration 400 / 1500: loss 2.818092
# iteration 500 / 1500: loss 2.765850
# iteration 600 / 1500: loss 2.598349
# iteration 700 / 1500: loss 2.548012
# iteration 800 / 1500: loss 2.522036
# iteration 900 / 1500: loss 2.594264
# iteration 1000 / 1500: loss 2.517097
# iteration 1100 / 1500: loss 2.380115
# iteration 1200 / 1500: loss 2.426677
# iteration 1300 / 1500: loss 2.253547
# iteration 1400 / 1500: loss 2.285229
# iteration 1500 / 1500: loss 2.197571
# iteration 100 / 1500: loss 5.973851
# iteration 200 / 1500: loss 5.697435
# iteration 300 / 1500: loss 5.351069
# iteration 400 / 1500: loss 5.173091
# iteration 500 / 1500: loss 4.887971
# iteration 600 / 1500: loss 4.553125
# iteration 700 / 1500: loss 4.558272
# iteration 800 / 1500: loss 4.204067
# iteration 900 / 1500: loss 4.076308
# iteration 1000 / 1500: loss 3.829308
# iteration 1100 / 1500: loss 3.732104
# iteration 1200 / 1500: loss 3.515922
# iteration 1300 / 1500: loss 3.448198
# iteration 1400 / 1500: loss 3.287349
# iteration 1500 / 1500: loss 3.306935
# iteration 100 / 1500: loss 1.002574
# iteration 200 / 1500: loss 0.903537
# iteration 300 / 1500: loss 0.980975
# iteration 400 / 1500: loss 0.873248
# iteration 500 / 1500: loss 0.769403
# iteration 600 / 1500: loss 0.701719
# iteration 700 / 1500: loss 0.724968
# iteration 800 / 1500: loss 0.766005
# iteration 900 / 1500: loss 0.659871
# iteration 1000 / 1500: loss 0.677269
# iteration 1100 / 1500: loss 0.565537
# iteration 1200 / 1500: loss 0.677166
# iteration 1300 / 1500: loss 0.581746
# iteration 1400 / 1500: loss 0.675902
# iteration 1500 / 1500: loss 0.584207
# iteration 100 / 1500: loss 1.063145
# iteration 200 / 1500: loss 1.040825
# iteration 300 / 1500: loss 0.933575
# iteration 400 / 1500: loss 0.901920
# iteration 500 / 1500: loss 0.805995
# iteration 600 / 1500: loss 0.859442
# iteration 700 / 1500: loss 0.791197
# iteration 800 / 1500: loss 0.717361
# iteration 900 / 1500: loss 0.743851
# iteration 1000 / 1500: loss 0.688581
# iteration 1100 / 1500: loss 0.713579
# iteration 1200 / 1500: loss 0.721595
# iteration 1300 / 1500: loss 0.685057
# iteration 1400 / 1500: loss 0.586945
# iteration 1500 / 1500: loss 0.661530
# iteration 100 / 1500: loss 5.181710
# iteration 200 / 1500: loss 5.035171
# iteration 300 / 1500: loss 4.841310
# iteration 400 / 1500: loss 4.666310
# iteration 500 / 1500: loss 4.670940
# iteration 600 / 1500: loss 4.595281
# iteration 700 / 1500: loss 4.388874
# iteration 800 / 1500: loss 4.369009
# iteration 900 / 1500: loss 4.323644
# iteration 1000 / 1500: loss 4.157704
# iteration 1100 / 1500: loss 4.097027
# iteration 1200 / 1500: loss 4.071995
# iteration 1300 / 1500: loss 3.937221
# iteration 1400 / 1500: loss 3.908770
# iteration 1500 / 1500: loss 3.785750
# iteration 100 / 1500: loss 11.214174
# iteration 200 / 1500: loss 10.524145
# iteration 300 / 1500: loss 10.062621
# iteration 400 / 1500: loss 9.636873
# iteration 500 / 1500: loss 9.172328
# iteration 600 / 1500: loss 8.745647
# iteration 700 / 1500: loss 8.275571
# iteration 800 / 1500: loss 8.002851
# iteration 900 / 1500: loss 7.483836
# iteration 1000 / 1500: loss 7.294591
# iteration 1100 / 1500: loss 6.880646
# iteration 1200 / 1500: loss 6.579352
# iteration 1300 / 1500: loss 6.330877
# iteration 1400 / 1500: loss 6.072673
# iteration 1500 / 1500: loss 5.776806
# lr 1.000000e-07 hidden_size 32.000000 reg 0.000000 train accuracy: 0.225000 val accuracy: 0.225000
# lr 1.000000e-07 hidden_size 32.000000 reg 0.001000 train accuracy: 0.220000 val accuracy: 0.257000
# lr 1.000000e-07 hidden_size 32.000000 reg 0.100000 train accuracy: 0.265000 val accuracy: 0.253000
# lr 1.000000e-07 hidden_size 32.000000 reg 0.250000 train accuracy: 0.285000 val accuracy: 0.287000
# lr 1.000000e-07 hidden_size 64.000000 reg 0.000000 train accuracy: 0.255000 val accuracy: 0.265000
# lr 1.000000e-07 hidden_size 64.000000 reg 0.001000 train accuracy: 0.215000 val accuracy: 0.221000
# lr 1.000000e-07 hidden_size 64.000000 reg 0.100000 train accuracy: 0.270000 val accuracy: 0.274000
# lr 1.000000e-07 hidden_size 64.000000 reg 0.250000 train accuracy: 0.220000 val accuracy: 0.252000
# lr 1.000000e-07 hidden_size 128.000000 reg 0.000000 train accuracy: 0.250000 val accuracy: 0.289000
# lr 1.000000e-07 hidden_size 128.000000 reg 0.001000 train accuracy: 0.185000 val accuracy: 0.204000
# lr 1.000000e-07 hidden_size 128.000000 reg 0.100000 train accuracy: 0.225000 val accuracy: 0.203000
# lr 1.000000e-07 hidden_size 128.000000 reg 0.250000 train accuracy: 0.245000 val accuracy: 0.289000
# lr 1.000000e-07 hidden_size 256.000000 reg 0.000000 train accuracy: 0.245000 val accuracy: 0.265000
# lr 1.000000e-07 hidden_size 256.000000 reg 0.001000 train accuracy: 0.200000 val accuracy: 0.222000
# lr 1.000000e-07 hidden_size 256.000000 reg 0.100000 train accuracy: 0.210000 val accuracy: 0.233000
# lr 1.000000e-07 hidden_size 256.000000 reg 0.250000 train accuracy: 0.275000 val accuracy: 0.281000
# lr 1.000000e-06 hidden_size 32.000000 reg 0.000000 train accuracy: 0.205000 val accuracy: 0.181000
# lr 1.000000e-06 hidden_size 32.000000 reg 0.001000 train accuracy: 0.220000 val accuracy: 0.229000
# lr 1.000000e-06 hidden_size 32.000000 reg 0.100000 train accuracy: 0.215000 val accuracy: 0.236000
# lr 1.000000e-06 hidden_size 32.000000 reg 0.250000 train accuracy: 0.175000 val accuracy: 0.248000
# lr 1.000000e-06 hidden_size 64.000000 reg 0.000000 train accuracy: 0.325000 val accuracy: 0.254000
# lr 1.000000e-06 hidden_size 64.000000 reg 0.001000 train accuracy: 0.220000 val accuracy: 0.278000
# lr 1.000000e-06 hidden_size 64.000000 reg 0.100000 train accuracy: 0.225000 val accuracy: 0.227000
# lr 1.000000e-06 hidden_size 64.000000 reg 0.250000 train accuracy: 0.195000 val accuracy: 0.215000
# lr 1.000000e-06 hidden_size 128.000000 reg 0.000000 train accuracy: 0.260000 val accuracy: 0.247000
# lr 1.000000e-06 hidden_size 128.000000 reg 0.001000 train accuracy: 0.225000 val accuracy: 0.207000
# lr 1.000000e-06 hidden_size 128.000000 reg 0.100000 train accuracy: 0.240000 val accuracy: 0.277000
# lr 1.000000e-06 hidden_size 128.000000 reg 0.250000 train accuracy: 0.260000 val accuracy: 0.249000
# lr 1.000000e-06 hidden_size 256.000000 reg 0.000000 train accuracy: 0.280000 val accuracy: 0.355000
# lr 1.000000e-06 hidden_size 256.000000 reg 0.001000 train accuracy: 0.345000 val accuracy: 0.298000
# lr 1.000000e-06 hidden_size 256.000000 reg 0.100000 train accuracy: 0.285000 val accuracy: 0.284000
# lr 1.000000e-06 hidden_size 256.000000 reg 0.250000 train accuracy: 0.325000 val accuracy: 0.305000
# lr 1.000000e-05 hidden_size 32.000000 reg 0.000000 train accuracy: 0.330000 val accuracy: 0.255000
# lr 1.000000e-05 hidden_size 32.000000 reg 0.001000 train accuracy: 0.340000 val accuracy: 0.309000
# lr 1.000000e-05 hidden_size 32.000000 reg 0.100000 train accuracy: 0.265000 val accuracy: 0.272000
# lr 1.000000e-05 hidden_size 32.000000 reg 0.250000 train accuracy: 0.335000 val accuracy: 0.329000
# lr 1.000000e-05 hidden_size 64.000000 reg 0.000000 train accuracy: 0.365000 val accuracy: 0.337000
# lr 1.000000e-05 hidden_size 64.000000 reg 0.001000 train accuracy: 0.340000 val accuracy: 0.321000
# lr 1.000000e-05 hidden_size 64.000000 reg 0.100000 train accuracy: 0.330000 val accuracy: 0.333000
# lr 1.000000e-05 hidden_size 64.000000 reg 0.250000 train accuracy: 0.370000 val accuracy: 0.359000
# lr 1.000000e-05 hidden_size 128.000000 reg 0.000000 train accuracy: 0.350000 val accuracy: 0.409000
# lr 1.000000e-05 hidden_size 128.000000 reg 0.001000 train accuracy: 0.410000 val accuracy: 0.421000
# lr 1.000000e-05 hidden_size 128.000000 reg 0.100000 train accuracy: 0.420000 val accuracy: 0.382000
# lr 1.000000e-05 hidden_size 128.000000 reg 0.250000 train accuracy: 0.440000 val accuracy: 0.415000
# lr 1.000000e-05 hidden_size 256.000000 reg 0.000000 train accuracy: 0.480000 val accuracy: 0.457000
# lr 1.000000e-05 hidden_size 256.000000 reg 0.001000 train accuracy: 0.455000 val accuracy: 0.450000
# lr 1.000000e-05 hidden_size 256.000000 reg 0.100000 train accuracy: 0.445000 val accuracy: 0.413000
# lr 1.000000e-05 hidden_size 256.000000 reg 0.250000 train accuracy: 0.480000 val accuracy: 0.458000
# lr 1.000000e-04 hidden_size 32.000000 reg 0.000000 train accuracy: 0.415000 val accuracy: 0.428000
# lr 1.000000e-04 hidden_size 32.000000 reg 0.001000 train accuracy: 0.430000 val accuracy: 0.435000
# lr 1.000000e-04 hidden_size 32.000000 reg 0.100000 train accuracy: 0.475000 val accuracy: 0.428000
# lr 1.000000e-04 hidden_size 32.000000 reg 0.250000 train accuracy: 0.365000 val accuracy: 0.434000
# lr 1.000000e-04 hidden_size 64.000000 reg 0.000000 train accuracy: 0.495000 val accuracy: 0.490000
# lr 1.000000e-04 hidden_size 64.000000 reg 0.001000 train accuracy: 0.485000 val accuracy: 0.512000
# lr 1.000000e-04 hidden_size 64.000000 reg 0.100000 train accuracy: 0.550000 val accuracy: 0.473000
# lr 1.000000e-04 hidden_size 64.000000 reg 0.250000 train accuracy: 0.500000 val accuracy: 0.508000
# lr 1.000000e-04 hidden_size 128.000000 reg 0.000000 train accuracy: 0.590000 val accuracy: 0.568000
# lr 1.000000e-04 hidden_size 128.000000 reg 0.001000 train accuracy: 0.530000 val accuracy: 0.575000
# lr 1.000000e-04 hidden_size 128.000000 reg 0.100000 train accuracy: 0.605000 val accuracy: 0.564000
# lr 1.000000e-04 hidden_size 128.000000 reg 0.250000 train accuracy: 0.620000 val accuracy: 0.562000
# lr 1.000000e-04 hidden_size 256.000000 reg 0.000000 train accuracy: 0.575000 val accuracy: 0.629000
# lr 1.000000e-04 hidden_size 256.000000 reg 0.001000 train accuracy: 0.655000 val accuracy: 0.621000
# lr 1.000000e-04 hidden_size 256.000000 reg 0.100000 train accuracy: 0.685000 val accuracy: 0.616000
# lr 1.000000e-04 hidden_size 256.000000 reg 0.250000 train accuracy: 0.660000 val accuracy: 0.619000
# lr 1.000000e-03 hidden_size 32.000000 reg 0.000000 train accuracy: 0.755000 val accuracy: 0.687000
# lr 1.000000e-03 hidden_size 32.000000 reg 0.001000 train accuracy: 0.690000 val accuracy: 0.682000
# lr 1.000000e-03 hidden_size 32.000000 reg 0.100000 train accuracy: 0.760000 val accuracy: 0.686000
# lr 1.000000e-03 hidden_size 32.000000 reg 0.250000 train accuracy: 0.785000 val accuracy: 0.687000
# lr 1.000000e-03 hidden_size 64.000000 reg 0.000000 train accuracy: 0.775000 val accuracy: 0.688000
# lr 1.000000e-03 hidden_size 64.000000 reg 0.001000 train accuracy: 0.770000 val accuracy: 0.682000
# lr 1.000000e-03 hidden_size 64.000000 reg 0.100000 train accuracy: 0.750000 val accuracy: 0.677000
# lr 1.000000e-03 hidden_size 64.000000 reg 0.250000 train accuracy: 0.735000 val accuracy: 0.672000
# lr 1.000000e-03 hidden_size 128.000000 reg 0.000000 train accuracy: 0.715000 val accuracy: 0.704000
# lr 1.000000e-03 hidden_size 128.000000 reg 0.001000 train accuracy: 0.735000 val accuracy: 0.699000
# lr 1.000000e-03 hidden_size 128.000000 reg 0.100000 train accuracy: 0.720000 val accuracy: 0.698000
# lr 1.000000e-03 hidden_size 128.000000 reg 0.250000 train accuracy: 0.785000 val accuracy: 0.696000
# lr 1.000000e-03 hidden_size 256.000000 reg 0.000000 train accuracy: 0.790000 val accuracy: 0.706000
# lr 1.000000e-03 hidden_size 256.000000 reg 0.001000 train accuracy: 0.825000 val accuracy: 0.704000
# lr 1.000000e-03 hidden_size 256.000000 reg 0.100000 train accuracy: 0.795000 val accuracy: 0.704000
# lr 1.000000e-03 hidden_size 256.000000 reg 0.250000 train accuracy: 0.730000 val accuracy: 0.711000
# best validation accuracy achieved during cross-validation: 0.711000
# Neural Network on raw pixels final test set accuracy: 0.734000

# %% [markdown]
# # **Best Model**
#
# **Learning rate**: 0.001
#
# **Hidden size**: 256
#
# **Regularization**: 0.25

# %%
best_test_acc = test_accuracies[(best_lr, best_hidden_size, best_reg)]
fig, axes = plt.subplots(1, 2)

axes[0].plot(best_losses)
axes[0].set_title('Loss history')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')

axes[1].plot(best_train_acc, label='train', marker='o', markerfacecolor='black')
axes[1].plot(best_val_acc, label='val', marker='o', markerfacecolor='black')
axes[1].plot([len(best_train_acc)-1], best_test_acc, label=f'test {best_test_acc}', marker='o', markerfacecolor='black')
axes[1].set_title('Classification accuracy history')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Clasification accuracy')
plt.legend()
plt.show()
# Out:
# (0.001, 256, 0.25)
# {(1e-07, 32, 0): 0.227, (1e-07, 32, 0.001): 0.258, (1e-07, 32, 0.1): 0.266, (1e-07, 32, 0.25): 0.275, (1e-07, 64, 0): 0.247, (1e-07, 64, 0.001): 0.196, (1e-07, 64, 0.1): 0.288, (1e-07, 64, 0.25): 0.245, (1e-07, 128, 0): 0.276, (1e-07, 128, 0.001): 0.189, (1e-07, 128, 0.1): 0.216, (1e-07, 128, 0.25): 0.297, (1e-07, 256, 0): 0.264, (1e-07, 256, 0.001): 0.236, (1e-07, 256, 0.1): 0.255, (1e-07, 256, 0.25): 0.284, (1e-06, 32, 0): 0.169, (1e-06, 32, 0.001): 0.252, (1e-06, 32, 0.1): 0.239, (1e-06, 32, 0.25): 0.229, (1e-06, 64, 0): 0.274, (1e-06, 64, 0.001): 0.278, (1e-06, 64, 0.1): 0.255, (1e-06, 64, 0.25): 0.207, (1e-06, 128, 0): 0.262, (1e-06, 128, 0.001): 0.239, (1e-06, 128, 0.1): 0.251, (1e-06, 128, 0.25): 0.241, (1e-06, 256, 0): 0.331, (1e-06, 256, 0.001): 0.292, (1e-06, 256, 0.1): 0.268, (1e-06, 256, 0.25): 0.339, (1e-05, 32, 0): 0.289, (1e-05, 32, 0.001): 0.322, (1e-05, 32, 0.1): 0.314, (1e-05, 32, 0.25): 0.323, (1e-05, 64, 0): 0.36, (1e-05, 64, 0.001): 0.326, (1e-05, 64, 0.1): 0.384, (1e-05, 64, 0.25): 0.368, (1e-05, 128, 0): 0.438, (1e-05, 128, 0.001): 0.426, (1e-05, 128, 0.1): 0.422, (1e-05, 128, 0.25): 0.421, (1e-05, 256, 0): 0.493, (1e-05, 256, 0.001): 0.465, (1e-05, 256, 0.1): 0.449, (1e-05, 256, 0.25): 0.505, (0.0001, 32, 0): 0.451, (0.0001, 32, 0.001): 0.438, (0.0001, 32, 0.1): 0.447, (0.0001, 32, 0.25): 0.45, (0.0001, 64, 0): 0.512, (0.0001, 64, 0.001): 0.552, (0.0001, 64, 0.1): 0.508, (0.0001, 64, 0.25): 0.516, (0.0001, 128, 0): 0.584, (0.0001, 128, 0.001): 0.6, (0.0001, 128, 0.1): 0.604, (0.0001, 128, 0.25): 0.583, (0.0001, 256, 0): 0.657, (0.0001, 256, 0.001): 0.648, (0.0001, 256, 0.1): 0.639, (0.0001, 256, 0.25): 0.653, (0.001, 32, 0): 0.691, (0.001, 32, 0.001): 0.708, (0.001, 32, 0.1): 0.699, (0.001, 32, 0.25): 0.715, (0.001, 64, 0): 0.701, (0.001, 64, 0.001): 0.706, (0.001, 64, 0.1): 0.698, (0.001, 64, 0.25): 0.71, (0.001, 128, 0): 0.708, (0.001, 128, 0.001): 0.735, (0.001, 128, 0.1): 0.732, (0.001, 128, 0.25): 0.716, (0.001, 256, 0): 0.733, (0.001, 256, 0.001): 0.73, (0.001, 256, 0.1): 0.74, (0.001, 256, 0.25): 0.734}

# %% [markdown]
# # Question

# %% [markdown]
# ##**Question:**
# What can you say about the training? Why does it take much longer to train (compare to hw1)? **(5 Points)**
#
# **Your answer:** The training process takes much longer due to the network's depth:
# - **Forward Pass**: Forward pass takes longer due to more fully connected - relu blocks.
#
# - **Backward Pass**: Backward pass takes longer due to the increased amount of weights and biases, taking derivatives with respect to more variables.
#
# - **Activation Function**: In comparison to a simple one fully connected neural network, in the 3 layers deep network activation function (relu) was added, adding more computations to the training process.

# %% [markdown]
# ##**Question:**
#
# What can you say about the diffrence (or lack of thereof) between the validation and training accuracy? What can you say about the connection between the loss and the accuracy? **(5 Points)**
#
# **Q1: What can you say about the diffrence (or lack of thereof) between the validation and training accuracy?**
#
# **A1**: A difference between the validation and training accuracy exists or not, depending on the parameters the model was trained with.
#
# For example, as visualized below, training and validation accuracies of models trained with smaller regularization strengths and larger hidden size tend to diverge and differ. On the other hand, larger hidden size and high regularization strength resulted in similar training and validation accuracy.
#
# As learned in class, larger networks (in this case, more neurons) are more complex models, and are prone to overfitting and catching noises. This is where regularization comes handy, introducing a penalty term for more complex models, and discourage overfitting the data. Therefore, networks with a large hidden size which were trained with high regularization strength resulted in similar validation and training accuracy, and test accuracy as well.
#
# **Q2: What can you say about the connection between the loss and the accuracy?**
#
# **A2:**
# There is an inverse relationship between loss and accuracy. During the training process, the loss is minimized using backprop, encouraging the model to improve and reduces its loss. As a result, the model yield better results and the accuracy tends to increase. However, minimized loss doesn't guarentees perfect predictions/accuracy on the validation / test set (Overfitting the training data).
#
# A good example is visualized in the previous section above, where i visualized the best model's loss-accuracy inverse relationship.

# %%
for i, lr in enumerate(learning_rates):
  rows = len(hidden_sizes)
  columns = len(regularizations)
  fig, axes = plt.subplots(rows, columns, figsize=(15, 12))
  plt.subplots_adjust(hspace=1, wspace=0.5)

  for j, hidden_size in enumerate(hidden_sizes):
    for k, reg in enumerate(regularizations):
      # Accuracies
      train_acc, val_acc = results[(lr, hidden_size, reg)]
      test_acc = test_accuracies[(lr, hidden_size, reg)]
      last_train_acc = train_accs[(lr, hidden_size, reg)][-1]
      last_val_acc = val_accs[(lr, hidden_size, reg)][-1]
      axes[j, k].plot(train_accs[(lr, hidden_size, reg)], label=f'Train {last_train_acc}', marker='o', markerfacecolor='black')
      axes[j, k].plot(val_accs[(lr, hidden_size, reg)], label=f'Val {last_val_acc}', marker='o', markerfacecolor='black')
      axes[j, k].plot([14], test_accuracies[(lr, hidden_size, reg)], label=f'Test {test_accuracies[(lr, hidden_size, reg)]}', marker='o', markerfacecolor='black')
      axes[j, k].legend(prop={"size":7})
      axes[j, k].set_title(f'Accuracy History\nlr={lr}, hid_size={hidden_size}, reg={reg}')
      axes[j, k].set_xlabel('Epoch')
      axes[j, k].set_ylabel('Accuracy')

  plt.show()
plt.show()

# %% [markdown]
# # The End
